# %% [markdown]
# # PISA 2012 Dataset Exploration
# ## by Maryse Bonhomme
#
# ## Preliminary Wrangling
#
# > PISA is the OECD's Program for International Students Assessment. The dataset that will be used today for analysis is the PISA 2012 survey, assessing 15 years old from 65 countries in  reading, mathematics and science.  And ultimately measure how well, those children are prepared for the future. <br>
# The PISA survey is conducted every 3 years. we are using the responses from the PISA 2012 survey. <br>
# That survey covered many areas of the 15 years old life, asking questions about life at school and also outside school.<br>
# The results this huge dataset with more than 600  variables and responses from almost 510, 000 students ( 485490 rows are part of this dataset).

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("darkgrid")

# %matplotlib inline

# %% [markdown]
# > *Load in your dataset and describe its properties through the questions below.
# Try and motivate your exploration goals through this section.
# The dataset covers a broad areas of the 15 years old. As part of the analysis today, I will focus  on the following questions:*
# * How does do Students who uses the internet at home differs from children who don't use internet at home in terms of scores?
# * How do children who reported playing video games compares to the one who don't?
# * I was also very interested by the cognitive activation section of the survey. how do children who reports being always encouraged to finding their own formulation to problems compares to those who are not really encouraged to do so?
# * finally, how do non OECD and OECD countries perform in Math, science and reading?
# * Do boys and girls perform in the same ways on test, in OECD and non-OECD countries?
# <hr>
# * what is the distribution of scores in Math, reading and science <br>
# * Which countries perform best in each category?  <br>
# * since in real life, the ability to adapt to new context is crucial, I was very interested in the cognitive activation section of the survey. in which countries are children most encouraged to find to think on their own, are given the freedom to explore different ways of finding answers. <br>
#
# of course this is a survey and what we are measuring is the perception those 15 years old have of being encouraged to  think more deeply about what they have learning in school. and ultimalty might make them more intelligent.
# In many educational system, academy success does not depend only on the ability to understand but also on other abilities like the ability to memorize for example. <br>
# I am personally convinced that in real life, that ability is crucial. but in this analysis, I am interested in understanding if there is any correlation with scores.
#
# <hr>

# %%
#loading the dataset
pd.set_option('display.max_columns', None)
df = pd.read_csv('pisa2012.csv',encoding='cp1252')
# Out:
# C:\Users\gwiza\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# using panda's sample to visually check the data
df.sample(10)
# Out:
#         Unnamed: 0                   CNT  SUBNATIO  STRATUM      OECD  \
# 299088      299089             Lithuania   4400000  LTU0015  Non-OECD
# 7049          7050  United Arab Emirates   7840100  ARE0109  Non-OECD
# 346807      346808                Mexico   4840000  MEX1955      OECD
# 408642      408643         Florida (USA)   8400100  QUA9797  Non-OECD
# 209879      209880       Hong Kong-China   3440000  HKG0002  Non-OECD
# 255473      255474                 Italy   3800000  ITA1301      OECD
# 129032      129033        Czech Republic   2030000  CZE3179      OECD
# 116979      116980              Colombia   1700000  COL0101  Non-OECD
# 214013      214014               Croatia   1910000  HRV0005  Non-OECD
# 395517      395518                 Qatar   6340000  QAT0001  Non-OECD
#
#                                NC  SCHOOLID  STIDSTD  ST01Q01  ST02Q01  \
# 299088                  Lithuania       132     2903        9      4.0
# 7049        United Arab Emirates         94     2307       10      2.0
# 346807                    Mexico       1352    31105       10      8.0
# 408642  United States of America         43     1488       10      1.0
# 209879            Hong Kong-China        96     2979       10      1.0
# 255473                      Italy       564    14884       10      1.0
# 129032            Czech Republic         69     1259       10      6.0
# 116979                  Colombia        117     2881       11      2.0
# 214013                    Croatia        79     2443        9      1.0
# 395517                      Qatar        84     6267       10      3.0
#
#         ST03Q01  ST03Q02 ST04Q01                      ST05Q01  ST06Q01  \
# 299088        3     1996  Female  Yes, for more than one year      8.0
# 7049          9     1996  Female   Yes, for one year or less       6.0
# 346807        6     1996    Male  Yes, for more than one year      6.0
# 408642        1     1997    Male  Yes, for more than one year      5.0
# 209879       10     1996    Male  Yes, for more than one year      6.0
# 255473        8     1996  Female  Yes, for more than one year      6.0
# 129032        5     1996  Female  Yes, for more than one year      6.0
# 116979        2     1996  Female   Yes, for one year or less       6.0
# 214013        7     1996  Female                         No        7.0
# 395517       12     1996  Female  Yes, for more than one year      6.0
#
#           ST07Q01    ST07Q02    ST07Q03             ST08Q01  \
# 299088  No, never  No, never        NaN              None
# 7049    No, never  No, never  No, never              None
# 346807  No, never  No, never  No, never              None
# 408642  No, never  No, never  No, never              None
# 209879  No, never  No, never  No, never              None
# 255473  No, never  No, never  No, never  One or two times
# 129032  No, never  No, never        NaN              None
# 116979  No, never  No, never  No, never              None
# 214013  No, never  No, never  No, never              None
# 395517  No, never  No, never  No, never              None
#
#                    ST09Q01  ST115Q01 ST11Q01 ST11Q02 ST11Q03 ST11Q04 ST11Q05  \
# 299088              None         1.0     Yes      No     Yes     NaN     NaN
# 7049    One or two times         1.0     Yes     Yes     Yes     Yes     Yes
# 346807              None         1.0     Yes     Yes     NaN     Yes     NaN
# 408642  One or two times         2.0     Yes     Yes      No     Yes      No
# 209879              None         1.0     Yes     Yes      No     Yes      No
# 255473              None         1.0     Yes     Yes     Yes      No      No
# 129032              None         1.0     Yes     Yes     Yes     Yes     NaN
# 116979              None         2.0     Yes     NaN     NaN     NaN     Yes
# 214013              None         1.0     Yes     Yes     Yes      No     Yes
# 395517              None         1.0     Yes     NaN     NaN     NaN     NaN
#
#        ST11Q06                ST13Q01 ST14Q01 ST14Q02 ST14Q03 ST14Q04  \
# 299088     NaN      <ISCED level 3A>      NaN     NaN     NaN     Yes
# 7049        No       <ISCED level 2>       No      No      No      No
# 346807     NaN       <ISCED level 2>      NaN     NaN     NaN     NaN
# 408642      No      <ISCED level 3A>       No     Yes     Yes     Yes
# 209879      No  <ISCED level 3B, 3C>       No     Yes      No      No
# 255473      No      <ISCED level 3A>       No     Yes      No      No
# 129032     NaN  <ISCED level 3B, 3C>       No      No      No      No
# 116979     NaN       <ISCED level 1>      NaN     NaN     NaN     NaN
# 214013      No      <ISCED level 3A>       No      No      No      No
# 395517     NaN      <ISCED level 3A>       No     Yes      No      No
#
#                                    ST15Q01                ST17Q01 ST18Q01  \
# 299088         Working part-time <for pay>      <ISCED level 3A>      NaN
# 7049    Other (e.g. home duties, retired)       <ISCED level 3A>       No
# 346807        Working full-time <for pay>        <ISCED level 1>      NaN
# 408642         Working part-time <for pay>      <ISCED level 3A>       No
# 209879         Working part-time <for pay>  <ISCED level 3B, 3C>      Yes
# 255473         Working part-time <for pay>      <ISCED level 3A>       No
# 129032  Other (e.g. home duties, retired)       <ISCED level 3A>       No
# 116979         Working part-time <for pay>                    NaN     NaN
# 214013  Other (e.g. home duties, retired)   <ISCED level 3B, 3C>       No
# 395517  Other (e.g. home duties, retired)                     NaN     NaN
#
#        ST18Q02 ST18Q03 ST18Q04                       ST19Q01          ST20Q01  \
# 299088     NaN     Yes     NaN   Working part-time <for pay>  Country of test
# 7049        No     Yes     Yes  Working full-time <for pay>   Country of test
# 346807     NaN     NaN     NaN  Working full-time <for pay>   Country of test
# 408642     Yes     Yes     Yes  Working full-time <for pay>     Other country
# 209879     Yes      No      No  Working full-time <for pay>   Country of test
# 255473     Yes      No      No  Working full-time <for pay>   Country of test
# 129032      No     Yes      No  Working full-time <for pay>   Country of test
# 116979     NaN     NaN     NaN                           NaN  Country of test
# 214013      No      No      No  Working full-time <for pay>     Other country
# 395517     NaN     NaN     NaN                           NaN  Country of test
#
#                 ST20Q02          ST20Q03  ST21Q01               ST25Q01  \
# 299088  Country of test  Country of test      NaN  Language of the test
# 7049    Country of test  Country of test      NaN  Language of the test
# 346807  Country of test  Country of test      NaN  Language of the test
# 408642  Country of test  Country of test      0.0  Language of the test
# 209879  Country of test  Country of test      NaN  Language of the test
# 255473  Country of test  Country of test      NaN  Language of the test
# 129032  Country of test  Country of test      NaN  Language of the test
# 116979  Country of test  Country of test      NaN  Language of the test
# 214013    Other country  Country of test     15.0                   NaN
# 395517  Country of test  Country of test      NaN        Other language
#
#        ST26Q01 ST26Q02 ST26Q03 ST26Q04 ST26Q05 ST26Q06 ST26Q07 ST26Q08  \
# 299088     Yes     Yes     Yes     Yes     Yes     Yes      No      No
# 7049       Yes     Yes     Yes     Yes     Yes     Yes      No      No
# 346807     Yes     Yes     NaN     Yes     Yes     NaN     NaN     NaN
# 408642      No     Yes      No     Yes      No     Yes      No      No
# 209879     Yes     Yes     Yes     Yes      No     Yes     Yes      No
# 255473     Yes     Yes     Yes     Yes     Yes     Yes      No     Yes
# 129032     Yes      No     Yes     Yes      No     Yes      No      No
# 116979     Yes     NaN     NaN     Yes     Yes     Yes     Yes     Yes
# 214013     Yes     Yes     Yes     Yes      No     Yes      No      No
# 395517      No     Yes      No     Yes     Yes     Yes     Yes     Yes
#
#        ST26Q09 ST26Q10 ST26Q11 ST26Q12 ST26Q13 ST26Q14  ST26Q15  ST26Q16  \
# 299088     Yes     Yes      No     Yes     Yes     Yes   440001   440002
# 7049        No     Yes     Yes     Yes     Yes     Yes   784001   784001
# 346807     NaN     NaN     NaN     Yes     Yes     Yes  9999999   484001
# 408642      No      No      No      No     Yes     Yes   840002   840002
# 209879      No     Yes     Yes     Yes      No     Yes   344001   344001
# 255473      No     Yes     Yes     Yes     Yes     Yes   380001   380001
# 129032      No     Yes     Yes     Yes     Yes     Yes   203001   203001
# 116979     Yes     Yes      No     Yes     Yes     Yes   170001   170002
# 214013     Yes     Yes      No     Yes     Yes     Yes   191001   191002
# 395517     Yes      No     Yes     Yes      No     Yes   634001   634002
#
#         ST26Q17        ST27Q01        ST27Q02        ST27Q03        ST27Q04  \
# 299088   440002  Three or more            Two            Two            Two
# 7049     784001  Three or more  Three or more  Three or more  Three or more
# 346807   484001  Three or more  Three or more            NaN           None
# 408642   840002  Three or more  Three or more            Two            Two
# 209879   344002  Three or more            Two  Three or more           None
# 255473   380001  Three or more  Three or more  Three or more  Three or more
# 129032   203001  Three or more  Three or more  Three or more            Two
# 116979   170001            Two            Two            One           None
# 214013   191001  Three or more            Two            One            Two
# 395517   634001  Three or more  Three or more            Two  Three or more
#
#               ST27Q05        ST28Q01         ST29Q01         ST29Q02  \
# 299088            One  26-100 books              NaN             NaN
# 7049    Three or more    0-10 books   Strongly agree  Strongly agree
# 346807           None    0-10 books              NaN             NaN
# 408642            Two  26-100 books   Strongly agree  Strongly agree
# 209879            One    0-10 books            Agree           Agree
# 255473  Three or more   11-25 books         Disagree        Disagree
# 129032            Two    0-10 books         Disagree           Agree
# 116979           None  26-100 books              NaN             NaN
# 214013            One    0-10 books         Disagree        Disagree
# 395517  Three or more   11-25 books            Agree  Strongly agree
#
#                   ST29Q03         ST29Q04         ST29Q05         ST29Q06  \
# 299088                NaN             NaN             NaN             NaN
# 7049       Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 346807                NaN             NaN             NaN             NaN
# 408642  Strongly disagree  Strongly agree  Strongly agree  Strongly agree
# 209879     Strongly agree  Strongly agree  Strongly agree           Agree
# 255473           Disagree           Agree           Agree        Disagree
# 129032           Disagree        Disagree           Agree        Disagree
# 116979                NaN             NaN             NaN             NaN
# 214013           Disagree        Disagree        Disagree        Disagree
# 395517  Strongly disagree        Disagree           Agree        Disagree
#
#                ST29Q07         ST29Q08         ST35Q01         ST35Q02  \
# 299088             NaN             NaN             NaN             NaN
# 7049    Strongly agree  Strongly agree  Strongly agree           Agree
# 346807             NaN             NaN             NaN             NaN
# 408642  Strongly agree  Strongly agree        Disagree        Disagree
# 209879  Strongly agree           Agree           Agree        Disagree
# 255473        Disagree           Agree           Agree        Disagree
# 129032           Agree           Agree           Agree        Disagree
# 116979             NaN             NaN             NaN             NaN
# 214013        Disagree           Agree        Disagree        Disagree
# 395517           Agree        Disagree  Strongly agree  Strongly agree
#
#                   ST35Q03         ST35Q04         ST35Q05         ST35Q06  \
# 299088                NaN             NaN             NaN             NaN
# 7049                Agree  Strongly agree  Strongly agree  Strongly agree
# 346807                NaN             NaN             NaN             NaN
# 408642  Strongly disagree           Agree           Agree        Disagree
# 209879              Agree        Disagree           Agree        Disagree
# 255473           Disagree           Agree           Agree           Agree
# 129032           Disagree           Agree           Agree        Disagree
# 116979                NaN             NaN             NaN             NaN
# 214013           Disagree           Agree           Agree        Disagree
# 395517              Agree  Strongly agree           Agree           Agree
#
#                    ST37Q01             ST37Q02             ST37Q03  \
# 299088                 NaN                 NaN                 NaN
# 7049    Not very confident      Very confident      Very confident
# 346807                 NaN                 NaN                 NaN
# 408642      Very confident      Very confident      Very confident
# 209879           Confident      Very confident      Very confident
# 255473           Confident  Not very confident           Confident
# 129032           Confident           Confident  Not very confident
# 116979                 NaN                 NaN                 NaN
# 214013           Confident           Confident           Confident
# 395517      Very confident      Very confident      Very confident
#
#                ST37Q04             ST37Q05             ST37Q06  \
# 299088             NaN                 NaN                 NaN
# 7049    Very confident      Very confident           Confident
# 346807             NaN                 NaN                 NaN
# 408642  Very confident      Very confident      Very confident
# 209879  Very confident      Very confident      Very confident
# 255473       Confident           Confident  Not very confident
# 129032       Confident  Not very confident           Confident
# 116979             NaN                 NaN                 NaN
# 214013       Confident           Confident  Not very confident
# 395517  Very confident      Very confident      Very confident
#
#                    ST37Q07             ST37Q08            ST42Q01  \
# 299088                 NaN                 NaN           Disagree
# 7049        Very confident  Not very confident     Strongly agree
# 346807                 NaN                 NaN     Strongly agree
# 408642      Very confident      Very confident  Strongly disagree
# 209879      Very confident           Confident           Disagree
# 255473           Confident  Not very confident              Agree
# 129032  Not very confident           Confident                NaN
# 116979                 NaN                 NaN     Strongly agree
# 214013           Confident  Not very confident              Agree
# 395517      Very confident      Very confident                NaN
#
#                   ST42Q02            ST42Q03            ST42Q04  \
# 299088  Strongly disagree  Strongly disagree              Agree
# 7049             Disagree     Strongly agree     Strongly agree
# 346807     Strongly agree           Disagree           Disagree
# 408642  Strongly disagree  Strongly disagree     Strongly agree
# 209879           Disagree           Disagree              Agree
# 255473           Disagree           Disagree              Agree
# 129032                NaN                NaN                NaN
# 116979              Agree              Agree           Disagree
# 214013     Strongly agree           Disagree  Strongly disagree
# 395517                NaN                NaN                NaN
#
#                   ST42Q05         ST42Q06            ST42Q07  \
# 299088           Disagree           Agree              Agree
# 7049             Disagree  Strongly agree     Strongly agree
# 346807              Agree        Disagree           Disagree
# 408642  Strongly disagree  Strongly agree     Strongly agree
# 209879           Disagree           Agree              Agree
# 255473           Disagree           Agree              Agree
# 129032                NaN             NaN                NaN
# 116979              Agree        Disagree           Disagree
# 214013           Disagree        Disagree  Strongly disagree
# 395517                NaN             NaN                NaN
#
#                   ST42Q08            ST42Q09            ST42Q10  \
# 299088           Disagree              Agree              Agree
# 7049    Strongly disagree     Strongly agree     Strongly agree
# 346807              Agree     Strongly agree              Agree
# 408642  Strongly disagree     Strongly agree  Strongly disagree
# 209879           Disagree              Agree           Disagree
# 255473           Disagree           Disagree              Agree
# 129032                NaN                NaN                NaN
# 116979              Agree           Disagree     Strongly agree
# 214013  Strongly disagree  Strongly disagree     Strongly agree
# 395517                NaN                NaN                NaN
#
#                ST43Q01            ST43Q02   ST43Q03         ST43Q04  \
# 299088             NaN                NaN       NaN             NaN
# 7049    Strongly agree     Strongly agree     Agree  Strongly agree
# 346807             NaN                NaN       NaN             NaN
# 408642  Strongly agree     Strongly agree     Agree  Strongly agree
# 209879           Agree     Strongly agree  Disagree        Disagree
# 255473           Agree              Agree  Disagree        Disagree
# 129032           Agree              Agree  Disagree        Disagree
# 116979             NaN                NaN       NaN             NaN
# 214013           Agree              Agree  Disagree        Disagree
# 395517           Agree  Strongly disagree     Agree  Strongly agree
#
#                   ST43Q05            ST43Q06            ST44Q01  \
# 299088                NaN                NaN                NaN
# 7049       Strongly agree  Strongly disagree      Very   Likely
# 346807                NaN                NaN                NaN
# 408642     Strongly agree  Strongly disagree  Not at all likely
# 209879     Strongly agree           Disagree    Slightly likely
# 255473           Disagree           Disagree             Likely
# 129032              Agree              Agree             Likely
# 116979                NaN                NaN                NaN
# 214013              Agree  Strongly disagree      Very   Likely
# 395517  Strongly disagree              Agree             Likely
#
#                   ST44Q03            ST44Q04            ST44Q05  \
# 299088                NaN                NaN                NaN
# 7049               Likely      Very   Likely      Very   Likely
# 346807                NaN                NaN                NaN
# 408642      Very   Likely  Not at all likely  Not at all likely
# 209879  Not at all likely    Slightly likely  Not at all likely
# 255473             Likely      Very   Likely      Very   Likely
# 129032             Likely    Slightly likely             Likely
# 116979                NaN                NaN                NaN
# 214013             Likely      Very   Likely      Very   Likely
# 395517      Very   Likely             Likely      Very   Likely
#
#                   ST44Q07            ST44Q08            ST46Q01  \
# 299088                NaN                NaN                NaN
# 7049      Slightly likely    Slightly likely              Agree
# 346807                NaN                NaN                NaN
# 408642      Very   Likely  Not at all likely  Strongly disagree
# 209879  Not at all likely      Very   Likely              Agree
# 255473             Likely    Slightly likely           Disagree
# 129032    Slightly likely             Likely              Agree
# 116979                NaN                NaN                NaN
# 214013      Very   Likely      Very   Likely              Agree
# 395517      Very   Likely             Likely           Disagree
#
#                   ST46Q02         ST46Q03            ST46Q04  \
# 299088                NaN             NaN                NaN
# 7049                Agree           Agree              Agree
# 346807                NaN             NaN                NaN
# 408642  Strongly disagree  Strongly agree  Strongly disagree
# 209879              Agree           Agree              Agree
# 255473              Agree           Agree              Agree
# 129032           Disagree        Disagree           Disagree
# 116979                NaN             NaN                NaN
# 214013              Agree        Disagree           Disagree
# 395517     Strongly agree        Disagree              Agree
#
#                   ST46Q05            ST46Q06            ST46Q07  \
# 299088                NaN                NaN                NaN
# 7049                Agree     Strongly agree     Strongly agree
# 346807                NaN                NaN                NaN
# 408642  Strongly disagree  Strongly disagree  Strongly disagree
# 209879              Agree              Agree              Agree
# 255473              Agree              Agree              Agree
# 129032              Agree              Agree              Agree
# 116979                NaN                NaN                NaN
# 214013           Disagree              Agree              Agree
# 395517     Strongly agree              Agree              Agree
#
#                   ST46Q08            ST46Q09  \
# 299088                NaN                NaN
# 7049       Strongly agree     Strongly agree
# 346807                NaN                NaN
# 408642  Strongly disagree  Strongly disagree
# 209879     Strongly agree     Strongly agree
# 255473                NaN              Agree
# 129032           Disagree           Disagree
# 116979                NaN                NaN
# 214013           Disagree              Agree
# 395517     Strongly agree              Agree
#
#                                    ST48Q01                   ST48Q02  \
# 299088                                 NaN                       NaN
# 7049             Courses after school Math     Major in college Math
# 346807                                 NaN                       NaN
# 408642           Courses after school Math  Major in college Science
# 209879           Courses after school Math     Major in college Math
# 255473  Courses after school Test Language     Major in college Math
# 129032           Courses after school Math  Major in college Science
# 116979                                 NaN                       NaN
# 214013           Courses after school Math                       NaN
# 395517           Courses after school Math  Major in college Science
#
#                            ST48Q03                  ST48Q04  \
# 299088                         NaN                      NaN
# 7049             Study harder Math  Maximum classes Science
# 346807                         NaN                      NaN
# 408642           Study harder Math     Maximum classes Math
# 209879           Study harder Math     Maximum classes Math
# 255473           Study harder Math                      NaN
# 129032  Study harder Test Language  Maximum classes Science
# 116979                         NaN                      NaN
# 214013  Study harder Test Language     Maximum classes Math
# 395517  Study harder Test Language  Maximum classes Science
#
#                           ST48Q05                  ST49Q01  \
# 299088                        NaN                      NaN
# 7049       Pursuing a career Math  Always or almost always
# 346807                        NaN                      NaN
# 408642  Pursuing a career Science          Never or rarely
# 209879     Pursuing a career Math                Sometimes
# 255473     Pursuing a career Math          Never or rarely
# 129032  Pursuing a career Science          Never or rarely
# 116979                        NaN                      NaN
# 214013                        NaN                Sometimes
# 395517  Pursuing a career Science                    Often
#
#                         ST49Q02                  ST49Q03          ST49Q04  \
# 299088                      NaN                      NaN              NaN
# 7049    Always or almost always  Always or almost always            Often
# 346807                      NaN                      NaN              NaN
# 408642          Never or rarely          Never or rarely  Never or rarely
# 209879                Sometimes                Sometimes  Never or rarely
# 255473                Sometimes          Never or rarely  Never or rarely
# 129032          Never or rarely          Never or rarely  Never or rarely
# 116979                      NaN                      NaN              NaN
# 214013          Never or rarely          Never or rarely  Never or rarely
# 395517                Sometimes          Never or rarely  Never or rarely
#
#                 ST49Q05                  ST49Q06                  ST49Q07  \
# 299088              NaN                      NaN                      NaN
# 7049          Sometimes          Never or rarely                Sometimes
# 346807              NaN                      NaN                      NaN
# 408642  Never or rarely  Always or almost always  Always or almost always
# 209879        Sometimes                    Often  Always or almost always
# 255473        Sometimes          Never or rarely          Never or rarely
# 129032  Never or rarely                Sometimes                Sometimes
# 116979              NaN                      NaN                      NaN
# 214013  Never or rarely                Sometimes                Sometimes
# 395517        Sometimes          Never or rarely          Never or rarely
#
#                 ST49Q09            ST53Q01                ST53Q02  \
# 299088              NaN  relating to known           check memory
# 7049          Sometimes                NaN                    NaN
# 346807              NaN           by heart  Improve understanding
# 408642  Never or rarely                NaN                    NaN
# 209879  Never or rarely                NaN                    NaN
# 255473  Never or rarely                NaN                    NaN
# 129032  Never or rarely     Most important  Improve understanding
# 116979              NaN     Most important           check memory
# 214013  Never or rarely                NaN                    NaN
# 395517  Never or rarely     Most important  Improve understanding
#
#                            ST53Q03           ST53Q04  \
# 299088  Relating to other subjects   Repeat examples
# 7049                           NaN               NaN
# 346807              learning goals     everyday life
# 408642                         NaN               NaN
# 209879                         NaN               NaN
# 255473                         NaN               NaN
# 129032              learning goals   Repeat examples
# 116979              learning goals  more information
# 214013                         NaN               NaN
# 395517              learning goals   Repeat examples
#
#                                                   ST55Q01  \
# 299088  I do not attend <out-of-school time lessons> i...
# 7049                                                  NaN
# 346807                                                NaN
# 408642                                                NaN
# 209879                                                NaN
# 255473                                                NaN
# 129032                           Less than 2 hours a week
# 116979                                                NaN
# 214013                                                NaN
# 395517  I do not attend <out-of-school time lessons> i...
#
#                                                   ST55Q02  \
# 299088  I do not attend <out-of-school time lessons> i...
# 7049                                                  NaN
# 346807                                                NaN
# 408642                                                NaN
# 209879                                                NaN
# 255473                                                NaN
# 129032  I do not attend <out-of-school time lessons> i...
# 116979                                                NaN
# 214013                                                NaN
# 395517             2 or more but less than 4 hours a week
#
#                                                   ST55Q03  \
# 299088  I do not attend <out-of-school time lessons> i...
# 7049                                                  NaN
# 346807                                                NaN
# 408642                                                NaN
# 209879                                                NaN
# 255473                                                NaN
# 129032  I do not attend <out-of-school time lessons> i...
# 116979                                                NaN
# 214013                                                NaN
# 395517                           Less than 2 hours a week
#
#                                                   ST55Q04  ST57Q01  ST57Q02  \
# 299088  I do not attend <out-of-school time lessons> i...      NaN      0.0
# 7049                                                  NaN      NaN      NaN
# 346807                             6 or more hours a week      5.0      NaN
# 408642                                                NaN      NaN      NaN
# 209879                                                NaN      NaN      NaN
# 255473                                                NaN      NaN      NaN
# 129032  I do not attend <out-of-school time lessons> i...      4.0      NaN
# 116979                                                NaN      2.0      1.0
# 214013                                                NaN      NaN      NaN
# 395517                           Less than 2 hours a week      5.0      0.0
#
#         ST57Q03  ST57Q04  ST57Q05  ST57Q06     ST61Q01    ST61Q02    ST61Q03  \
# 299088      0.0      0.0      4.0      5.0     Rarely      Never   Sometimes
# 7049        NaN      NaN      NaN      NaN         NaN        NaN        NaN
# 346807      0.0      0.0      0.0      0.0  Frequently  Sometimes     Never
# 408642      NaN      NaN      NaN      NaN         NaN        NaN        NaN
# 209879      NaN      NaN      NaN      NaN         NaN        NaN        NaN
# 255473      NaN      NaN      NaN      NaN         NaN        NaN        NaN
# 129032      NaN      NaN      2.0      5.0   Sometimes    Rarely     Rarely
# 116979      NaN      NaN      NaN      2.0   Sometimes  Sometimes    Rarely
# 214013      NaN      NaN      NaN      NaN         NaN        NaN        NaN
# 395517      2.0      0.0      0.0      0.0      Never     Rarely     Rarely
#
#           ST61Q04     ST61Q05    ST61Q06     ST61Q07    ST61Q08     ST61Q09  \
# 299088  Sometimes  Frequently  Sometimes  Frequently  Sometimes  Frequently
# 7049          NaN         NaN        NaN         NaN        NaN         NaN
# 346807    Rarely       Never      Never       Never   Sometimes      Never
# 408642        NaN         NaN        NaN         NaN        NaN         NaN
# 209879        NaN         NaN        NaN         NaN        NaN         NaN
# 255473        NaN         NaN        NaN         NaN        NaN         NaN
# 129032  Sometimes  Frequently  Sometimes  Frequently    Rarely    Sometimes
# 116979    Rarely    Sometimes    Rarely    Sometimes  Sometimes   Sometimes
# 214013        NaN         NaN        NaN         NaN        NaN         NaN
# 395517    Rarely   Frequently    Rarely   Frequently     Never   Frequently
#
#                           ST62Q01                                ST62Q02  \
# 299088          Never heard of it                      Heard of it often
# 7049                          NaN                                    NaN
# 346807          Never heard of it                Heard of it a few times
# 408642                        NaN                                    NaN
# 209879                        NaN                                    NaN
# 255473                        NaN                                    NaN
# 129032  Heard of it once or twice  Know it well,  understand the concept
# 116979          Heard of it often  Know it well,  understand the concept
# 214013                        NaN                                    NaN
# 395517          Never heard of it  Know it well,  understand the concept
#
#                                       ST62Q03  \
# 299088                      Heard of it often
# 7049                                      NaN
# 346807              Heard of it once or twice
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032              Heard of it once or twice
# 116979                      Heard of it often
# 214013                                    NaN
# 395517  Know it well,  understand the concept
#
#                                       ST62Q04  \
# 299088                Heard of it a few times
# 7049                                      NaN
# 346807                Heard of it a few times
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032              Heard of it once or twice
# 116979                      Heard of it often
# 214013                                    NaN
# 395517  Know it well,  understand the concept
#
#                                       ST62Q06  \
# 299088                      Heard of it often
# 7049                                      NaN
# 346807              Heard of it once or twice
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032              Heard of it once or twice
# 116979  Know it well,  understand the concept
# 214013                                    NaN
# 395517                      Never heard of it
#
#                                       ST62Q07  \
# 299088                      Never heard of it
# 7049                                      NaN
# 346807                      Never heard of it
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032                      Never heard of it
# 116979  Know it well,  understand the concept
# 214013                                    NaN
# 395517                      Never heard of it
#
#                                       ST62Q08                  ST62Q09  \
# 299088                      Never heard of it  Heard of it a few times
# 7049                                      NaN                      NaN
# 346807                Heard of it a few times  Heard of it a few times
# 408642                                    NaN                      NaN
# 209879                                    NaN                      NaN
# 255473                                    NaN                      NaN
# 129032                      Never heard of it  Heard of it a few times
# 116979                      Heard of it often        Heard of it often
# 214013                                    NaN                      NaN
# 395517  Know it well,  understand the concept        Never heard of it
#
#                                       ST62Q10                    ST62Q11  \
# 299088                      Heard of it often          Never heard of it
# 7049                                      NaN                        NaN
# 346807              Heard of it once or twice          Never heard of it
# 408642                                    NaN                        NaN
# 209879                                    NaN                        NaN
# 255473                                    NaN                        NaN
# 129032  Know it well,  understand the concept  Heard of it once or twice
# 116979  Know it well,  understand the concept  Heard of it once or twice
# 214013                                    NaN                        NaN
# 395517                      Never heard of it          Never heard of it
#
#                                       ST62Q12  \
# 299088                      Heard of it often
# 7049                                      NaN
# 346807  Know it well,  understand the concept
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032  Know it well,  understand the concept
# 116979  Know it well,  understand the concept
# 214013                                    NaN
# 395517  Know it well,  understand the concept
#
#                                       ST62Q13                    ST62Q15  \
# 299088                      Never heard of it    Heard of it a few times
# 7049                                      NaN                        NaN
# 346807                      Never heard of it  Heard of it once or twice
# 408642                                    NaN                        NaN
# 209879                                    NaN                        NaN
# 255473                                    NaN                        NaN
# 129032              Heard of it once or twice    Heard of it a few times
# 116979              Heard of it once or twice          Heard of it often
# 214013                                    NaN                        NaN
# 395517  Know it well,  understand the concept          Never heard of it
#
#                                       ST62Q16  \
# 299088              Heard of it once or twice
# 7049                                      NaN
# 346807  Know it well,  understand the concept
# 408642                                    NaN
# 209879                                    NaN
# 255473                                    NaN
# 129032                Heard of it a few times
# 116979  Know it well,  understand the concept
# 214013                                    NaN
# 395517                      Never heard of it
#
#                                       ST62Q17                    ST62Q19  \
# 299088                      Never heard of it  Heard of it once or twice
# 7049                                      NaN                        NaN
# 346807              Heard of it once or twice          Never heard of it
# 408642                                    NaN                        NaN
# 209879                                    NaN                        NaN
# 255473                                    NaN                        NaN
# 129032              Heard of it once or twice          Heard of it often
# 116979                Heard of it a few times    Heard of it a few times
# 214013                                    NaN                        NaN
# 395517  Know it well,  understand the concept          Never heard of it
#
#         ST69Q01  ST69Q02  ST69Q03  ST70Q01  ST70Q02  ST70Q03  ST71Q01  \
# 299088     45.0     45.0     45.0      4.0      4.0      7.0     34.0
# 7049        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 346807      NaN      NaN      NaN      0.0      0.0      0.0      5.0
# 408642      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 209879      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 255473      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 129032     45.0     45.0     45.0      1.0      1.0      2.0     37.0
# 116979    120.0    120.0    120.0      2.0      4.0      3.0      NaN
# 214013      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 395517     60.0     60.0     60.0      4.0      5.0      5.0      NaN
#
#         ST72Q01     ST73Q01     ST73Q02     ST74Q01     ST74Q02     ST75Q01  \
# 299088     25.0   Sometimes   Sometimes  Frequently  Frequently   Sometimes
# 7049        NaN         NaN         NaN         NaN         NaN         NaN
# 346807      NaN  Frequently     Rarely   Frequently  Frequently   Sometimes
# 408642      NaN         NaN         NaN         NaN         NaN         NaN
# 209879      NaN         NaN         NaN         NaN         NaN         NaN
# 255473      NaN         NaN         NaN         NaN         NaN         NaN
# 129032     22.0   Sometimes   Sometimes   Sometimes   Sometimes     Rarely
# 116979     22.0   Sometimes  Frequently   Sometimes  Frequently  Frequently
# 214013      NaN         NaN         NaN         NaN         NaN         NaN
# 395517      NaN  Frequently   Sometimes  Frequently  Frequently  Frequently
#
#            ST75Q02     ST76Q01    ST76Q02               ST77Q01  \
# 299088   Sometimes   Sometimes  Sometimes          Most Lessons
# 7049           NaN         NaN        NaN          Most Lessons
# 346807   Sometimes  Frequently     Never           Every Lesson
# 408642         NaN         NaN        NaN  Never or Hardly Ever
# 209879         NaN         NaN        NaN          Most Lessons
# 255473         NaN         NaN        NaN          Every Lesson
# 129032     Rarely      Rarely     Rarely                    NaN
# 116979  Frequently   Sometimes  Sometimes          Most Lessons
# 214013         NaN         NaN        NaN          Some Lessons
# 395517  Frequently      Never     Rarely                    NaN
#
#                      ST77Q02               ST77Q04               ST77Q05  \
# 299088          Every Lesson          Most Lessons          Every Lesson
# 7049            Most Lessons          Some Lessons          Some Lessons
# 346807          Every Lesson          Most Lessons          Most Lessons
# 408642  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 209879          Every Lesson          Most Lessons          Most Lessons
# 255473          Most Lessons          Every Lesson          Every Lesson
# 129032                   NaN                   NaN                   NaN
# 116979          Most Lessons          Every Lesson          Every Lesson
# 214013  Never or Hardly Ever          Some Lessons          Every Lesson
# 395517                   NaN                   NaN                   NaN
#
#              ST77Q06               ST79Q01               ST79Q02  \
# 299088  Most Lessons          Most Lessons          Some Lessons
# 7049    Some Lessons          Most Lessons          Every Lesson
# 346807  Every Lesson          Every Lesson          Most Lessons
# 408642  Some Lessons  Never or Hardly Ever  Never or Hardly Ever
# 209879  Every Lesson          Some Lessons          Most Lessons
# 255473  Every Lesson          Most Lessons          Most Lessons
# 129032           NaN                   NaN                   NaN
# 116979  Most Lessons          Most Lessons          Every Lesson
# 214013  Every Lesson          Every Lesson          Some Lessons
# 395517           NaN                   NaN                   NaN
#
#                      ST79Q03               ST79Q04               ST79Q05  \
# 299088  Never or Hardly Ever  Never or Hardly Ever          Some Lessons
# 7049            Every Lesson          Most Lessons          Every Lesson
# 346807  Never or Hardly Ever          Some Lessons          Most Lessons
# 408642  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 209879  Never or Hardly Ever          Some Lessons          Some Lessons
# 255473  Never or Hardly Ever          Some Lessons          Some Lessons
# 129032                   NaN                   NaN                   NaN
# 116979          Most Lessons          Every Lesson          Some Lessons
# 214013          Some Lessons  Never or Hardly Ever  Never or Hardly Ever
# 395517                   NaN                   NaN                   NaN
#
#                      ST79Q06               ST79Q07               ST79Q08  \
# 299088          Every Lesson          Some Lessons          Every Lesson
# 7049            Every Lesson          Every Lesson          Every Lesson
# 346807          Every Lesson          Most Lessons          Every Lesson
# 408642  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 209879          Most Lessons  Never or Hardly Ever          Most Lessons
# 255473          Every Lesson  Never or Hardly Ever          Some Lessons
# 129032                   NaN                   NaN                   NaN
# 116979          Every Lesson          Every Lesson          Every Lesson
# 214013          Some Lessons  Never or Hardly Ever          Every Lesson
# 395517                   NaN                   NaN                   NaN
#
#                      ST79Q10               ST79Q11       ST79Q12  \
# 299088          Some Lessons          Some Lessons  Some Lessons
# 7049            Most Lessons          Most Lessons  Most Lessons
# 346807          Most Lessons  Never or Hardly Ever  Most Lessons
# 408642  Never or Hardly Ever  Never or Hardly Ever  Every Lesson
# 209879          Some Lessons          Most Lessons  Every Lesson
# 255473          Some Lessons          Most Lessons  Some Lessons
# 129032                   NaN                   NaN           NaN
# 116979          Most Lessons          Most Lessons  Every Lesson
# 214013  Never or Hardly Ever  Never or Hardly Ever  Most Lessons
# 395517                   NaN                   NaN           NaN
#
#                      ST79Q15               ST79Q17                  ST80Q01  \
# 299088          Every Lesson          Some Lessons                Sometimes
# 7049            Every Lesson          Every Lesson  Always or almost always
# 346807          Every Lesson          Every Lesson  Always or almost always
# 408642  Never or Hardly Ever  Never or Hardly Ever          Never or rarely
# 209879          Every Lesson          Every Lesson  Always or almost always
# 255473          Some Lessons          Some Lessons                    Often
# 129032                   NaN                   NaN                      NaN
# 116979          Every Lesson          Most Lessons                    Often
# 214013          Most Lessons  Never or Hardly Ever                Sometimes
# 395517                   NaN                   NaN                      NaN
#
#                         ST80Q04                  ST80Q05  \
# 299088                Sometimes                Sometimes
# 7049    Always or almost always  Always or almost always
# 346807                Sometimes                    Often
# 408642          Never or rarely          Never or rarely
# 209879  Always or almost always  Always or almost always
# 255473                Sometimes                Sometimes
# 129032                      NaN                      NaN
# 116979  Always or almost always  Always or almost always
# 214013                Sometimes          Never or rarely
# 395517                      NaN                      NaN
#
#                         ST80Q06          ST80Q07          ST80Q08  \
# 299088  Always or almost always            Often            Often
# ...
# 7049    405.9900  447.2737  472.1997  486.2206  504.9151  461.2946  478.4312
# 346807  392.9818  365.7190  357.9296  366.4979  383.6345  400.7711  370.3926
# 7049      7.3000    7.3000    2.4333    7.3000    2.4333        16         1
# 346807   31.5506   31.5506   10.0854    9.6994   30.2562        10         1
# 408642   61.2958  188.1304  188.1304  188.1304  188.1304        41         1
# 209879    6.3402   19.5084   18.5567    6.5028    6.3402        22         2
# 255473   42.3481   40.9488   13.5783   14.1553   14.1553         6         1
# 129032   34.9999   35.5384   35.5384   36.7132   11.6666        22         1
# 116979   15.3931   15.3931   46.1794   15.3931   46.1794         5         1
# 214013    3.5996    3.6426    3.5981    3.6426   10.7944        33         1
# 395517    1.5105    0.5035    1.5105    1.5035    0.5035        70         2
#
#         SENWGT_STU  VER_STU
# 299088      0.2423  22NOV13
# 7049        0.1198  22NOV13
# 346807      0.0152  22NOV13
# 408642      0.7131  22NOV13
# 209879      0.1795  22NOV13
# 255473      0.0533  22NOV13
# 129032      0.2837  22NOV13
# 116979      0.0550  22NOV13
# 214013      0.1592  22NOV13
# 395517      0.0913  22NOV13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Columns: 636 entries, Unnamed: 0 to VER_STU
# dtypes: float64(250), int64(18), object(368)
# memory usage: 2.3+ GB

# %%
df.shape
# Out:
# (485490, 636)

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The PISA dataset is a dataset with 636 columns and 495 489 rows.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > **_Video Game and Internet users Score_**: With the internet and video games being constantly critized for kids, I am really interested in observing if there any correlation between using the internet or playing video games and scores obtained. <br>
# > **_In term of cognitive Activation_**: Is there any correlation between children who are encouraged to think for themselves about problems, instead of being asking questions with obvious questions. <br>
# > **_Scores _**:Is there a difference in averages scores, for OECD and non OECD countries?
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > In order to find answers to those questions, I will keep informations on countries, respondents gender, cognitive activations questions and of course score. without forgetting responses on internet and video games.
# Below I am going to reduce the  original dataframe to only the column needed.
#
# <hr>
#
# 1. which countries have the highest sucess rates in term of scores in Math, Reading and Science?
# 2. Do girls and boys succeed in the same way?
# 3. do OCD and non OECD countries perform in the same way?
# 4. finally which countries give priority in their education system to cognitive activation? blabla
# 5. are this countries the best performing in test?  test or method
# 6. in term of cognition responses, is there a difference between boys and girls?

# %%
wanted_columns = ['CNT','OECD','ST01Q01','ST02Q01', 'ST04Q01','ST28Q01','ST53Q01','ST53Q02','ST80Q01','ST80Q04','ST80Q05',
                  'ST80Q06','ST80Q07', 'ST80Q08', 'ST80Q09', 'ST80Q10', 'ST80Q11','PV1MATH','PV2MATH','PV3MATH',
                  'PV4MATH','PV5MATH', 'PV1READ', 'PV2READ', 'PV3READ', 'PV4READ',
                  'PV5READ', 'PV1SCIE', 'PV2SCIE','PV3SCIE', 'PV4SCIE','PV5SCIE']

# %%
df_selected = df[wanted_columns].copy()

# %%
df_selected.sample(5)
# Out:
#                          CNT      OECD  ST01Q01  ST02Q01 ST04Q01  \
# 377512                  Peru  Non-OECD       10      1.0    Male
# 359730           Netherlands      OECD       10      2.0  Female
# 374368                  Peru  Non-OECD       10      1.0  Female
# 11709   United Arab Emirates  Non-OECD       10      1.0  Female
# 407540         Florida (USA)  Non-OECD       10      1.0  Female
#
#               ST28Q01   ST53Q01                ST53Q02  \
# 377512   11-25 books        NaN                    NaN
# 359730    0-10 books        NaN                    NaN
# 374368    0-10 books   by heart  Improve understanding
# 11709     0-10 books        NaN                    NaN
# 407540  26-100 books        NaN                    NaN
#
#                         ST80Q01                  ST80Q04  \
# 377512  Always or almost always                    Often
# 359730                Sometimes                Sometimes
# 374368                Sometimes                Sometimes
# 11709                 Sometimes                Sometimes
# 407540  Always or almost always  Always or almost always
#
#                         ST80Q05                  ST80Q06  \
# 377512                    Often  Always or almost always
# 359730                Sometimes                    Often
# 374368                Sometimes          Never or rarely
# 11709                 Sometimes          Never or rarely
# 407540  Always or almost always  Always or almost always
#
#                         ST80Q07                  ST80Q08  \
# 377512                    Often  Always or almost always
# 359730                Sometimes                Sometimes
# 374368  Always or almost always  Always or almost always
# 11709                 Sometimes                    Often
# 407540  Always or almost always  Always or almost always
#
#                         ST80Q09                  ST80Q10  \
# 377512  Always or almost always  Always or almost always
# 359730                    Often                Sometimes
# 374368  Always or almost always  Always or almost always
# 11709   Always or almost always                    Often
# 407540  Always or almost always  Always or almost always
#
#                         ST80Q11   PV1MATH   PV2MATH   PV3MATH   PV4MATH  \
# 377512  Always or almost always  457.4778  441.8990  443.4569  469.1619
# 359730                Sometimes  560.9986  525.9464  539.1883  568.7880
# 374368  Always or almost always  275.0506  258.6929  261.8087  197.9358
# 11709                 Sometimes  432.9413  445.4043  450.0779  431.3834
# 407540  Always or almost always  336.6646  397.4217  377.9483  367.8221
#
#          PV5MATH   PV1READ   PV2READ   PV3READ   PV4READ   PV5READ   PV1SCIE  \
# 377512  467.6040  487.6445  462.7842  448.3492  485.2387  455.5667  442.9690
# 359730  593.7140  510.1099  503.7554  508.5213  532.3506  524.4075  463.2040
# 374368  243.1142  404.3872  249.4967  281.2692  243.9366  347.1969  275.7740
# 11709   395.5523  438.6220  452.1253  455.3025  438.6220  417.1756  428.7020
# 407540  372.4957  454.4288  495.7329  464.7548  490.9670  467.1377  354.7557
#
#          PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 377512  454.1589  504.5132  512.9056  420.5893
# 359730  494.9086  469.7314  493.0436  493.0436
# 374368  288.8288  263.6516  266.4491  300.0186
# 11709   479.9888  478.1238  428.7020  336.3857
# 407540  461.0593  412.5699  420.0298  388.3253

# %%
# renaming the selected columns so that it is easier to understand
df_selected.rename(columns=
                   {'CNT':'country', 
                    'OECD':'OECD', 
                    'ST01Q01':'international_grade',
                    'ST02Q01':'national_study_program', 
                    'ST04Q01':'gender',
                    'ST28Q01':'number_books',
                    'ST53Q01':'Learning_strategies_1',
                    'ST53Q02':'Learning_strategies_2',
                    'ST80Q01':'CA_TeacherEncouragesToReflectProblems',
                    'ST80Q04':'CA_GivesProblemThatRequireToThink',
                    'ST80Q05':'CA_AsksToUseOwnProcedures',
                    'ST80Q06':'CA_PresentsProblemsWithNoObviousSolutions',
                    'ST80Q07':'CA_PresentsProblemsInDifferentContexts',
                    'ST80Q08':'CA_HelpsLearnFromMistakes',
                    'ST80Q09':'CA_AsksForExplanation',
                    'ST80Q10':'CA_ApplyWhatTheyLearned',
                    'ST80Q11':'CA_ProblemWithMultipleSolutions'}, inplace=True)

# %%
#checking if columns were renamed
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions   PV1MATH   PV2MATH   PV3MATH   PV4MATH  \
# 0                           Often  406.8469  376.4683  344.5319  321.1637
#
#     PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ   PV5READ   PV1SCIE  \
# 0  381.9209  249.5762  254.342  406.8496  175.7053  218.5981  341.7009
#
#    PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 0   408.84  348.2283  367.8105  392.9877

# %% [markdown]
# Each score is represented five time for each participants. so I am going to calculate an average value for each score, it will be easier to work with only one value.

# %%
df_selected['math_average'] =  (df_selected['PV1MATH'] + df_selected['PV2MATH']+ 
                                df_selected['PV3MATH'] + df_selected['PV4MATH'] + df_selected['PV5MATH'])/5
df_selected['reading_average'] = (df_selected ['PV1READ'] + df_selected['PV2READ']+ 
                          df_selected['PV3READ'] + df_selected ['PV4READ'] + df_selected['PV5READ'])/5
df_selected['science_average'] = (df_selected['PV1SCIE'] + df_selected ['PV2SCIE']+ 
                          df_selected['PV3SCIE'] + df_selected['PV4SCIE'] + df_selected['PV5SCIE'])/5

# %%
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions   PV1MATH   PV2MATH   PV3MATH   PV4MATH  \
# 0                           Often  406.8469  376.4683  344.5319  321.1637
#
#     PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ   PV5READ   PV1SCIE  \
# 0  381.9209  249.5762  254.342  406.8496  175.7053  218.5981  341.7009
#
#    PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE  math_average  reading_average  \
# 0   408.84  348.2283  367.8105  392.9877     366.18634        261.01424
#
#    science_average
# 0        371.91348

# %%
#since I no longoer need the individuals values for the dataframe, I am going to simply drop them
df_selected.drop(['PV1MATH', 'PV2MATH','PV3MATH', 'PV4MATH','PV5MATH','PV1READ','PV2READ','PV3READ','PV4READ','PV5READ', 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE'], axis=1, inplace=True)

# %%
df_selected.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  math_average  reading_average  \
# 0                           Often     366.18634        261.01424
# 1                             NaN     470.56396        384.68832
# 2                             NaN     505.53824        405.18154
# 3                 Never or rarely     449.45476        477.46376
# 4                           Often     385.50398        256.01010
#
#    science_average
# 0        371.91348
# 1        478.12382
# 2        486.60946
# 3        453.97240
# 4        367.15778

# %%
# I am now going to save the new dataframe to a csv file so that is quicker to laod 
df_selected.to_csv('PISA_cognition.csv', encoding='utf-8', index=False)

# %%
df_cognition = pd.read_csv('PISA_cognition.csv', encoding='utf-8')
df_cognition.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  math_average  reading_average  \
# 0                           Often     366.18634        261.01424
# 1                             NaN     470.56396        384.68832
# 2                             NaN     505.53824        405.18154
# 3                 Never or rarely     449.45476        477.46376
# 4                           Often     385.50398        256.01010
#
#    science_average
# 0        371.91348
# 1        478.12382
# 2        486.60946
# 3        453.97240
# 4        367.15778

# %%
df_cognition['math_average'].isnull().sum().sum(), df_cognition['reading_average'].isnull().sum().sum(), df_cognition['science_average'].isnull().sum().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.m

# %%
df_cognition['math_average'].mean(), df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()
# Out:
# (469.65123385442615, 472.0069640898506, 475.80809403002854)

# %%
# plotting Math, Reading and Science Score to see if children tends to succeed more in one  
labels = ["Math Score", "Reading Score", "Science Score"]
usage = [df_cognition['math_average'].mean(),df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()]

# Generating the y positions. Later, we'll use them to replace them with labels.
y_positions = range(len(labels))

# Creating our bar plot
plt.bar(y_positions, usage)
plt.xticks(y_positions, labels)
plt.ylabel("Score")
plt.title("Average Scores in Math, Reading and Science")
plt.show()

# %%
#proportion of OECD and non OECD respondents
OECD = df_cognition.query('OECD == "OECD"')
Non_OECD = df_cognition.query('OECD=="Non-OECD"')
OECD.shape[0], Non_OECD.shape[0]
# Out:
# (295416, 190074)

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['OECD'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',
        counterclock = False);
plt.axis('square');

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['gender'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',
        counterclock = False);
plt.axis('square');

# %%
# plotting Math, Reading and Science Score to see if children tends to succeed more in one  
labels = ["Math Score", "Reading Score", "Science Score"]
usage = [Non_OECD['math_average'].mean(),Non_OECD['reading_average'].mean(), Non_OECD['science_average'].mean()]

# Generating the y positions. Later, we'll use them to replace them with labels.
y_positions = range(len(labels))

# Creating our bar plot
plt.bar(y_positions, usage)
plt.xticks(y_positions, labels)
plt.ylabel("Score")
plt.title("Non OECD Countries average scores in Math, Reading and Science")
plt.show()

# %%
plt.figure(figsize = [17, 5])

bins_hist = np.arange(0, 1000 + 1, 100)

plt.subplot(1, 3, 1)
plt.hist(df_cognition['math_average'], bins = bins_hist, alpha = 0.7);

plt.xlim(0, 1000);
#plt.ylim(0, 180000 + 1);
plt.xticks(bins_hist)
plt.xlabel('Math Score');
plt.ylabel('Nr. of students')
plt.title("Math Score distribution across students");

plt.subplot(1, 3, 2)
plt.hist(df_cognition['reading_average'], bins = bins_hist,  alpha = 0.7);

plt.xlim(0, 1000);
#plt.ylim(0, 180000 + 1);
plt.xticks(bins_hist)
plt.xlabel('Reading Score');
plt.title("Reading Score distribution across students");

plt.subplot(1, 3, 3)
plt.hist(df_cognition['science_average'], bins = bins_hist, alpha = 0.7);

plt.xlim(0, 1000);
#plt.ylim(0, 180000 + 1);
plt.xticks(bins_hist)
plt.xlabel('Science Score');
plt.title("Science Score distribution across students");

# %%
df_cognition['OECD'].max()
# Out:
# 'OECD'

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!

# %% [markdown]
# ## References:
# * PISA 2012 contest winner: http://mi2.mini.pw.edu.pl:8080/SmarterPoland/PISAcontest/
# * What is PISA: http://www.oecd.org/pisa/
# * OECD: https://en.wikipedia.org/wiki/OECD
# * PISA 2012 Countries : http://www.oecd.org/pisa/aboutpisa/pisa-2012-participants.htm
# * PISA 2012 Data analysis Manual:http://archivos.agenciaeducacion.cl/Manual_de_Analisis_de_datos_SPSS_version_ingles.pdf
# * PISA Data Exploration : https://github.com/brunoassisp/PISA-Data-Viz-project/blob/master/PISA_EDA.ipynb
# * Jasccyang github repository : https://github.com/jasccyang/PISA2012/blob/master/Reducing%20File%20Size.ipynb
# * Seby Sbirna Github repository: https://github.com/seby-sbirna/Data-Analyst-Nanodegree-Project-Portfolio/blob/master/Project%205%20-%20Communicate%20Data%20Findings/Project%205%20-%20Sebastian%20Sbirna.ipynb
# * Visualization: https://www.researchgate.net/figure/Responses-to-Relating-to-your-last-five-publications-how-often-did-you-incorporate-the_fig1_328394497
# * Udacity Classroom: https://classroom.udacity.com/nanodegrees/nd002/parts/9f7e8991-8bfb-4103-8307-3b6f93f0ecc7
# * BarPlot with matplotlib: https://towardsdatascience.com/data-science-with-python-intro-to-data-visualization-and-matplotlib-5f799b7c6d82
