# %% [markdown]
# # PISA 2012 Dataset Exploration
# ## by Maryse Bonhomme
#
# ## Preliminary Wrangling
#
# > PISA is the [OECD's](https://en.wikipedia.org/wiki/OECD) Program for International Students Assessment. The goal of the Program is to assess 15 years old in order to evaluate their skills in Math, Reading and Science. And more importantly to evaluate how prepared to the future they are by asking all sort of questions.
# The Survey is done by PISA every 3 years, and assess various areas of the 15 years old. They assess the students life both inside school and out of school, including at home. Asking questions about possessions, family context and even how much mental stimulation the students get (cognitive activity).<p>The dataset that will be used today for analysis is the PISA 2012 survey, with participants from 65 countries.we are using the responses the survey.
# The results is a huge dataset with more than 636  variables and responses from almost 510, 000 students ( 485490 rows are part of this dataset).

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("darkgrid")

# %matplotlib inline

# %% [markdown]
# > The dataset covers a broad areas of the 15 years old. As part of the analysis today, I will focus  on the following questions:
# * In which Subject are students getting better scores?
# * Do OECD and Non_OECD perform in the tests?
# * On Math, Reading and Science tests, do boys and girls perform the same? is the score distribution the same?
# * How does the time spent on computer affect students scores? does it even have any impact on the students?
# * which countries have the biggest computer users?
# * Do boys and girls spend as much time on the computer? is there a difference between OECD and Non_OECD countries?
# * since in real life, the ability to adapt to new context is crucial, I was very interested in the cognitive activation section of the survey. Are children most encouraged to find to think on their own, are given the freedom to explore different ways of finding answers?  <br>
# * are there differences in the perception about cognitive activation between genders?
# * Are the trends the same in  OECD and Non_OECD Countries?

# %%
#loading the dataset
pd.set_option('display.max_columns', None)
df = pd.read_csv('pisa2012.csv',encoding='cp1252')
# Out:
# C:\Users\gwiza\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# using panda's sample to visually check the data
df.sample(10)
# Out:
#         Unnamed: 0                CNT  SUBNATIO  STRATUM      OECD  \
# 266178      266179              Italy   3800000  ITA1502      OECD
# 432641      432642             Serbia   6880000  SRB0010  Non-OECD
# 410269      410270  Connecticut (USA)   8400200  QUB9797  Non-OECD
# 18505        18506          Argentina    320000  ARG0005  Non-OECD
# 231921      231922            Ireland   3720000  IRL0006      OECD
# 377894      377895               Peru   6040000  PER0001  Non-OECD
# 60778        60779             Brazil    760000  BRA2778  Non-OECD
# 377184      377185               Peru   6040000  PER0002  Non-OECD
# 21389        21390          Argentina    320000  ARG0001  Non-OECD
# 216899      216900            Hungary   3480000  HUN0005      OECD
#
#                                NC  SCHOOLID  STIDSTD  ST01Q01  ST02Q01  \
# 266178                      Italy       974    25589       10      2.0
# 432641                    Serbia        142     4320        9      6.0
# 410269  United States of America         37     1219       10      1.0
# 18505                   Argentina        86     2263       10      5.0
# 231921                    Ireland       180     4911       11      4.0
# 377894                      Peru        195     5008       10      1.0
# 60778                     Brazil        250     5513       11      1.0
# 377184                      Peru        166     4298        9      1.0
# 21389                   Argentina       197     5147       10      5.0
# 216899                    Hungary        17      321        9      5.0
#
#         ST03Q01  ST03Q02 ST04Q01                      ST05Q01  ST06Q01  \
# 266178        7     1996  Female  Yes, for more than one year      6.0
# 432641        8     1996  Female   Yes, for one year or less       7.0
# 410269        1     1997  Female  Yes, for more than one year      5.0
# 18505         1     1997  Female   Yes, for one year or less       NaN
# 231921        5     1996  Female                         No        4.0
# 377894        8     1996  Female                         No        NaN
# 60778         3     1996    Male                         No        NaN
# 377184       11     1996    Male  Yes, for more than one year      NaN
# 21389        10     1996    Male  Yes, for more than one year      6.0
# 216899        8     1996  Female  Yes, for more than one year      7.0
#
#           ST07Q01             ST07Q02    ST07Q03             ST08Q01  \
# 266178  No, never           No, never  No, never              None
# 432641  No, never           No, never  No, never              None
# 410269  No, never           No, never  No, never              None
# 18505   No, never                 NaN        NaN  One or two times
# 231921  No, never           No, never  No, never  One or two times
# 377894  Yes, once                 NaN        NaN  One or two times
# 60778   No, never           No, never  No, never              None
# 377184  No, never  Yes, twice or more        NaN  One or two times
# 21389   No, never           No, never  No, never  One or two times
# 216899  No, never           No, never  No, never  One or two times
#
#                    ST09Q01  ST115Q01 ST11Q01 ST11Q02 ST11Q03 ST11Q04 ST11Q05  \
# 266178  One or two times         1.0     Yes     Yes      No     Yes      No
# 432641              None         1.0     Yes     Yes     Yes     Yes     Yes
# 410269              None         1.0     NaN     NaN     NaN     NaN     NaN
# 18505   One or two times         2.0     Yes     Yes     Yes     Yes      No
# 231921              None         1.0     Yes     Yes     Yes     Yes     NaN
# 377894              None         1.0     Yes     Yes     NaN     NaN     NaN
# 60778               None         1.0     Yes     NaN     NaN     NaN     NaN
# 377184              None         2.0     Yes     Yes      No      No      No
# 21389               None         1.0     Yes     Yes     Yes     Yes      No
# 216899              None         1.0     Yes     Yes     Yes      No      No
#
#        ST11Q06                                ST13Q01 ST14Q01 ST14Q02 ST14Q03  \
# 266178      No                       <ISCED level 2>       No      No      No
# 432641      No                  <ISCED level 3B, 3C>       No      No      No
# 410269     Yes                      <ISCED level 3A>      NaN     NaN     NaN
# 18505       No                       <ISCED level 1>      NaN     NaN     NaN
# 231921     NaN                      <ISCED level 3A>       No      No      No
# 377894     NaN  She did not complete <ISCED level 1>      NaN     NaN     NaN
# 60778      NaN                      <ISCED level 3A>      NaN     NaN     NaN
# 377184      No  She did not complete <ISCED level 1>       No      No      No
# 21389       No                       <ISCED level 2>       No      No      No
# 216899      No                       <ISCED level 2>       No      No      No
#
#        ST14Q04                             ST15Q01  \
# 266178      No  Other (e.g. home duties, retired)
# 432641     NaN        Working full-time <for pay>
# 410269     Yes        Working full-time <for pay>
# 18505      NaN  Other (e.g. home duties, retired)
# 231921     Yes         Working part-time <for pay>
# 377894     NaN                                 NaN
# 60778      NaN         Working part-time <for pay>
# 377184      No         Working part-time <for pay>
# 21389      NaN  Other (e.g. home duties, retired)
# 216899      No        Working full-time <for pay>
#
#                                      ST17Q01 ST18Q01 ST18Q02 ST18Q03 ST18Q04  \
# 266178  He did not complete <ISCED level 1>       No      No      No      No
# 432641                      <ISCED level 2>       No      No      No     NaN
# 410269                     <ISCED level 3A>      NaN     NaN     NaN     Yes
# 18505                       <ISCED level 1>       No      No      No     NaN
# 231921                     <ISCED level 3A>       No      No      No     Yes
# 377894                     <ISCED level 3A>      NaN     NaN     NaN     NaN
# 60778                       <ISCED level 2>      NaN     NaN     NaN     NaN
# 377184  He did not complete <ISCED level 1>       No      No      No      No
# 21389                       <ISCED level 2>       No      No      No     NaN
# 216899                      <ISCED level 2>       No      No      No      No
#
#                                    ST19Q01          ST20Q01          ST20Q02  \
# 266178        Working full-time <for pay>   Country of test  Country of test
# 432641  Other (e.g. home duties, retired)   Country of test  Country of test
# 410269  Other (e.g. home duties, retired)   Country of test  Country of test
# 18505         Working full-time <for pay>   Country of test  Country of test
# 231921        Working full-time <for pay>   Country of test  Country of test
# 377894                                 NaN  Country of test    Other country
# 60778                                  NaN  Country of test  Country of test
# 377184        Working full-time <for pay>   Country of test  Country of test
# 21389         Working full-time <for pay>   Country of test  Country of test
# 216899  Not working, but looking for a job  Country of test  Country of test
#
#                 ST20Q03  ST21Q01               ST25Q01 ST26Q01 ST26Q02  \
# 266178  Country of test      NaN  Language of the test     Yes     Yes
# 432641  Country of test      NaN  Language of the test     Yes     Yes
# 410269  Country of test      NaN  Language of the test      No      No
# 18505   Country of test      NaN  Language of the test     Yes     Yes
# 231921  Country of test      NaN  Language of the test     Yes     Yes
# 377894    Other country      NaN  Language of the test     NaN     Yes
# 60778   Country of test      NaN  Language of the test      No     Yes
# 377184  Country of test      NaN                   NaN     Yes     Yes
# 21389   Country of test      NaN  Language of the test     Yes      No
# 216899  Country of test      NaN  Language of the test     Yes     Yes
#
#        ST26Q03 ST26Q04 ST26Q05 ST26Q06 ST26Q07 ST26Q08 ST26Q09 ST26Q10  \
# 266178     Yes     Yes     Yes     Yes      No      No      No     Yes
# 432641     Yes      No      No      No     Yes     Yes     Yes     Yes
# 410269     Yes      No      No     Yes      No      No     Yes      No
# 18505      Yes     Yes     Yes      No     Yes     Yes      No     Yes
# 231921     Yes     Yes     Yes     Yes      No      No     Yes     Yes
# 377894     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes
# 60778      NaN     Yes     Yes     Yes      No      No      No     Yes
# 377184      No     Yes     Yes      No     Yes     Yes      No     Yes
# 21389      Yes     Yes     Yes     Yes     Yes     Yes      No     Yes
# 216899     Yes     Yes      No     Yes      No      No      No     Yes
#
#        ST26Q11 ST26Q12 ST26Q13 ST26Q14  ST26Q15  ST26Q16  ST26Q17  \
# 266178      No     Yes     Yes     Yes   380002   380002   380002
# 432641      No     Yes      No     Yes   688002   688002   688002
# 410269      No      No     Yes     Yes   840002   840002   840001
# 18505       No     Yes     Yes     Yes    32002    32001    32001
# 231921     Yes     Yes     Yes     Yes   372001   372002   372002
# 377894     Yes     Yes     NaN     Yes   604001   604001   604001
# 60778      Yes     Yes      No     Yes    76002    76002    76002
# 377184     Yes     Yes      No     Yes   604001   604001   604002
# 21389      Yes     Yes     Yes     Yes    32002    32002    32001
# 216899      No     Yes      No     Yes   348002   348002   348002
#
#               ST27Q01        ST27Q02 ST27Q03 ST27Q04        ST27Q05  \
# 266178  Three or more  Three or more     One     Two            One
# 432641  Three or more            Two     One     One            One
# 410269  Three or more  Three or more    None     Two            One
# 18505             Two            Two     One     Two           None
# 231921  Three or more  Three or more     Two     One  Three or more
# 377894            One            One     One     One            One
# 60778   Three or more            One     Two    None            One
# 377184            Two            Two     One     One           None
# 21389   Three or more            Two     Two    None            One
# 216899  Three or more  Three or more     Two     One            One
#
#               ST28Q01         ST29Q01         ST29Q02         ST29Q03  \
# 266178    0-10 books              NaN             NaN             NaN
# 432641    0-10 books         Disagree           Agree        Disagree
# 410269    0-10 books              NaN             NaN             NaN
# 18505    11-25 books            Agree  Strongly agree           Agree
# 231921  26-100 books   Strongly agree  Strongly agree  Strongly agree
# 377894   11-25 books            Agree  Strongly agree           Agree
# 60778    11-25 books            Agree  Strongly agree           Agree
# 377184   11-25 books            Agree           Agree           Agree
# 21389    11-25 books              NaN             NaN             NaN
# 216899  26-100 books         Disagree           Agree        Disagree
#
#                ST29Q04         ST29Q05         ST29Q06         ST29Q07  \
# 266178             NaN             NaN             NaN             NaN
# 432641        Disagree           Agree           Agree           Agree
# 410269             NaN             NaN             NaN             NaN
# 18505            Agree           Agree           Agree           Agree
# 231921  Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 377894             NaN  Strongly agree  Strongly agree  Strongly agree
# 60778         Disagree  Strongly agree           Agree           Agree
# 377184  Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 21389              NaN             NaN             NaN             NaN
# 216899        Disagree           Agree        Disagree           Agree
#
#                ST29Q08            ST35Q01            ST35Q02  \
# 266178             NaN                NaN                NaN
# 432641           Agree           Disagree           Disagree
# 410269             NaN                NaN                NaN
# 18505   Strongly agree     Strongly agree              Agree
# 231921  Strongly agree           Disagree           Disagree
# 377894  Strongly agree     Strongly agree              Agree
# 60778            Agree              Agree           Disagree
# 377184           Agree              Agree              Agree
# 21389              NaN                NaN                NaN
# 216899           Agree  Strongly disagree  Strongly disagree
#
#                   ST35Q03         ST35Q04         ST35Q05            ST35Q06  \
# 266178                NaN             NaN             NaN                NaN
# 432641           Disagree        Disagree        Disagree           Disagree
# 410269                NaN             NaN             NaN                NaN
# 18505            Disagree  Strongly agree  Strongly agree     Strongly agree
# 231921           Disagree           Agree           Agree           Disagree
# 377894              Agree  Strongly agree  Strongly agree     Strongly agree
# 60778            Disagree           Agree           Agree              Agree
# 377184           Disagree           Agree           Agree  Strongly disagree
# 21389                 NaN             NaN             NaN                NaN
# 216899  Strongly disagree           Agree           Agree           Disagree
#
#                      ST37Q01             ST37Q02             ST37Q03  \
# 266178                   NaN                 NaN                 NaN
# 432641    Not very confident  Not very confident                 NaN
# 410269                   NaN                 NaN                 NaN
# 18505     Not very confident           Confident  Not very confident
# 231921        Very confident      Very confident      Very confident
# 377894  Not at all confident           Confident           Confident
# 60778              Confident           Confident           Confident
# 377184             Confident           Confident      Very confident
# 21389                    NaN                 NaN                 NaN
# 216899             Confident           Confident           Confident
#
#                    ST37Q04             ST37Q05             ST37Q06  \
# 266178                 NaN                 NaN                 NaN
# 432641      Very confident      Very confident           Confident
# 410269                 NaN                 NaN                 NaN
# 18505   Not very confident           Confident  Not very confident
# 231921      Very confident      Very confident           Confident
# 377894           Confident      Very confident      Very confident
# 60778       Very confident           Confident           Confident
# 377184      Very confident      Very confident      Very confident
# 21389                  NaN                 NaN                 NaN
# 216899           Confident  Not very confident  Not very confident
#
#                    ST37Q07             ST37Q08         ST42Q01 ST42Q02  \
# 266178                 NaN                 NaN  Strongly agree   Agree
# 432641      Very confident      Very confident             NaN     NaN
# 410269                 NaN                 NaN  Strongly agree   Agree
# 18505   Not very confident           Confident             NaN     NaN
# 231921           Confident      Very confident             NaN     NaN
# 377894      Very confident           Confident             NaN     NaN
# 60778            Confident           Confident             NaN     NaN
# 377184           Confident  Not very confident             NaN     NaN
# 21389                  NaN                 NaN             NaN     NaN
# 216899  Not very confident           Confident           Agree   Agree
#
#          ST42Q03   ST42Q04            ST42Q05   ST42Q06   ST42Q07   ST42Q08  \
# 266178     Agree  Disagree     Strongly agree     Agree  Disagree     Agree
# 432641       NaN       NaN                NaN       NaN       NaN       NaN
# 410269  Disagree     Agree  Strongly disagree  Disagree     Agree     Agree
# 18505        NaN       NaN                NaN       NaN       NaN       NaN
# 231921       NaN       NaN                NaN       NaN       NaN       NaN
# 377894       NaN       NaN                NaN       NaN       NaN       NaN
# 60778        NaN       NaN                NaN       NaN       NaN       NaN
# 377184       NaN       NaN                NaN       NaN       NaN       NaN
# 21389        NaN       NaN                NaN       NaN       NaN       NaN
# 216899     Agree  Disagree              Agree  Disagree  Disagree  Disagree
#
#                   ST42Q09         ST42Q10         ST43Q01         ST43Q02  \
# 266178           Disagree  Strongly agree             NaN             NaN
# 432641                NaN             NaN           Agree  Strongly agree
# 410269  Strongly disagree  Strongly agree             NaN             NaN
# 18505                 NaN             NaN  Strongly agree  Strongly agree
# 231921                NaN             NaN  Strongly agree  Strongly agree
# 377894                NaN             NaN  Strongly agree  Strongly agree
# 60778                 NaN             NaN  Strongly agree  Strongly agree
# 377184                NaN             NaN  Strongly agree           Agree
# 21389                 NaN             NaN             NaN             NaN
# 216899           Disagree           Agree           Agree           Agree
#
#                ST43Q03            ST43Q04         ST43Q05   ST43Q06  \
# 266178             NaN                NaN             NaN       NaN
# 432641        Disagree              Agree           Agree  Disagree
# 410269             NaN                NaN             NaN       NaN
# 18505            Agree           Disagree  Strongly agree  Disagree
# 231921        Disagree  Strongly disagree           Agree  Disagree
# 377894  Strongly agree     Strongly agree  Strongly agree  Disagree
# 60778         Disagree           Disagree  Strongly agree     Agree
# 377184           Agree     Strongly agree  Strongly agree     Agree
# 21389              NaN                NaN             NaN       NaN
# 216899        Disagree              Agree        Disagree  Disagree
#
#                   ST44Q01            ST44Q03            ST44Q04  \
# 266178                NaN                NaN                NaN
# 432641             Likely      Very   Likely             Likely
# 410269                NaN                NaN                NaN
# 18505              Likely  Not at all likely             Likely
# 231921  Not at all likely             Likely    Slightly likely
# 377894    Slightly likely  Not at all likely  Not at all likely
# 60778       Very   Likely  Not at all likely  Not at all likely
# 377184    Slightly likely             Likely      Very   Likely
# 21389                 NaN                NaN                NaN
# 216899             Likely    Slightly likely    Slightly likely
#
#                   ST44Q05            ST44Q07            ST44Q08  \
# 266178                NaN                NaN                NaN
# 432641      Very   Likely             Likely      Very   Likely
# 410269                NaN                NaN                NaN
# 18505              Likely  Not at all likely             Likely
# 231921             Likely    Slightly likely    Slightly likely
# 377894  Not at all likely  Not at all likely  Not at all likely
# 60778       Very   Likely  Not at all likely    Slightly likely
# 377184             Likely      Very   Likely             Likely
# 21389                 NaN                NaN                NaN
# 216899             Likely             Likely    Slightly likely
#
#                ST46Q01         ST46Q02         ST46Q03         ST46Q04  \
# 266178             NaN             NaN             NaN             NaN
# 432641           Agree           Agree           Agree           Agree
# 410269             NaN             NaN             NaN             NaN
# 18505            Agree  Strongly agree  Strongly agree  Strongly agree
# 231921  Strongly agree           Agree  Strongly agree  Strongly agree
# 377894  Strongly agree  Strongly agree           Agree           Agree
# 60778            Agree           Agree        Disagree           Agree
# 377184           Agree           Agree  Strongly agree  Strongly agree
# 21389              NaN             NaN             NaN             NaN
# 216899        Disagree           Agree        Disagree        Disagree
#
#                ST46Q05         ST46Q06         ST46Q07         ST46Q08  \
# 266178             NaN             NaN             NaN             NaN
# 432641           Agree           Agree           Agree           Agree
# 410269             NaN             NaN             NaN             NaN
# 18505   Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 231921           Agree  Strongly agree  Strongly agree  Strongly agree
# 377894           Agree  Strongly agree  Strongly agree        Disagree
# 60778            Agree           Agree        Disagree           Agree
# 377184           Agree  Strongly agree  Strongly agree  Strongly agree
# 21389              NaN             NaN             NaN             NaN
# 216899           Agree           Agree           Agree        Disagree
#
#                ST46Q09                             ST48Q01  \
# 266178             NaN                                 NaN
# 432641        Disagree  Courses after school Test Language
# 410269             NaN                                 NaN
# 18505   Strongly agree  Courses after school Test Language
# 231921           Agree           Courses after school Math
# 377894  Strongly agree  Courses after school Test Language
# 60778            Agree  Courses after school Test Language
# 377184           Agree           Courses after school Math
# 21389              NaN                                 NaN
# 216899        Disagree           Courses after school Math
#
#                          ST48Q02                     ST48Q03  \
# 266178                       NaN                         NaN
# 432641  Major in college Science           Study harder Math
# 410269                       NaN                         NaN
# 18505   Major in college Science  Study harder Test Language
# 231921     Major in college Math           Study harder Math
# 377894  Major in college Science  Study harder Test Language
# 60778   Major in college Science           Study harder Math
# 377184     Major in college Math           Study harder Math
# 21389                        NaN                         NaN
# 216899  Major in college Science  Study harder Test Language
#
#                         ST48Q04                    ST48Q05          ST49Q01  \
# 266178                      NaN                        NaN              NaN
# 432641  Maximum classes Science  Pursuing a career Science            Often
# 410269                      NaN                        NaN              NaN
# 18505   Maximum classes Science  Pursuing a career Science            Often
# 231921     Maximum classes Math     Pursuing a career Math            Often
# 377894  Maximum classes Science  Pursuing a career Science        Sometimes
# 60778      Maximum classes Math  Pursuing a career Science        Sometimes
# 377184     Maximum classes Math     Pursuing a career Math        Sometimes
# 21389                       NaN                        NaN              NaN
# 216899  Maximum classes Science     Pursuing a career Math  Never or rarely
#
#                         ST49Q02                  ST49Q03  \
# 266178                      NaN                      NaN
# 432641                    Often                Sometimes
# 410269                      NaN                      NaN
# 18505                     Often                    Often
# 231921  Always or almost always          Never or rarely
# 377894                Sometimes  Always or almost always
# 60778                 Sometimes                Sometimes
# 377184                Sometimes          Never or rarely
# 21389                       NaN                      NaN
# 216899          Never or rarely          Never or rarely
#
#                         ST49Q04                  ST49Q05  \
# 266178                      NaN                      NaN
# 432641          Never or rarely                Sometimes
# 410269                      NaN                      NaN
# 18505           Never or rarely                Sometimes
# 231921          Never or rarely                Sometimes
# 377894  Always or almost always  Always or almost always
# 60778                 Sometimes          Never or rarely
# 377184                Sometimes  Always or almost always
# 21389                       NaN                      NaN
# 216899          Never or rarely          Never or rarely
#
#                         ST49Q06                  ST49Q07          ST49Q09  \
# 266178                      NaN                      NaN              NaN
# 432641                Sometimes          Never or rarely  Never or rarely
# 410269                      NaN                      NaN              NaN
# 18505   Always or almost always          Never or rarely  Never or rarely
# 231921          Never or rarely                Sometimes  Never or rarely
# 377894  Always or almost always  Always or almost always            Often
# 60778           Never or rarely          Never or rarely  Never or rarely
# 377184  Always or almost always  Always or almost always        Sometimes
# 21389                       NaN                      NaN              NaN
# 216899          Never or rarely                Sometimes  Never or rarely
#
#                   ST53Q01                ST53Q02                     ST53Q03  \
# 266178     Most important  Improve understanding              learning goals
# 432641     Most important           check memory                 in my sleep
# 410269  relating to known  Improve understanding  Relating to other subjects
# 18505      Most important  Improve understanding  Relating to other subjects
# 231921     Most important  Improve understanding                 in my sleep
# 377894                NaN                    NaN                         NaN
# 60778      Most important           check memory              learning goals
# 377184  relating to known               new ways              learning goals
# 21389      Most important               new ways              learning goals
# 216899                NaN                    NaN                         NaN
#
#                  ST53Q04                                            ST55Q01  \
# 266178  more information  I do not attend <out-of-school time lessons> i...
# 432641     everyday life  I do not attend <out-of-school time lessons> i...
# 410269  more information  I do not attend <out-of-school time lessons> i...
# 18505    Repeat examples  I do not attend <out-of-school time lessons> i...
# 231921  more information  I do not attend <out-of-school time lessons> i...
# 377894               NaN                                                NaN
# 60778   more information  I do not attend <out-of-school time lessons> i...
# 377184   Repeat examples                           Less than 2 hours a week
# 21389    Repeat examples  I do not attend <out-of-school time lessons> i...
# 216899               NaN                                                NaN
#
#                                                   ST55Q02  \
# 266178  I do not attend <out-of-school time lessons> i...
# 432641  I do not attend <out-of-school time lessons> i...
# 410269  I do not attend <out-of-school time lessons> i...
# 18505   I do not attend <out-of-school time lessons> i...
# 231921  I do not attend <out-of-school time lessons> i...
# 377894                                                NaN
# 60778   I do not attend <out-of-school time lessons> i...
# 377184             2 or more but less than 4 hours a week
# 21389   I do not attend <out-of-school time lessons> i...
# 216899                                                NaN
#
#                                                   ST55Q03  \
# 266178  I do not attend <out-of-school time lessons> i...
# 432641  I do not attend <out-of-school time lessons> i...
# 410269  I do not attend <out-of-school time lessons> i...
# 18505   I do not attend <out-of-school time lessons> i...
# 231921  I do not attend <out-of-school time lessons> i...
# 377894                                                NaN
# 60778   I do not attend <out-of-school time lessons> i...
# 377184                           Less than 2 hours a week
# 21389   I do not attend <out-of-school time lessons> i...
# 216899                                                NaN
#
#                                                   ST55Q04  ST57Q01  ST57Q02  \
# 266178  I do not attend <out-of-school time lessons> i...      2.0      NaN
# 432641  I do not attend <out-of-school time lessons> i...      2.0      NaN
# 410269  I do not attend <out-of-school time lessons> i...      0.0      0.0
# 18505   I do not attend <out-of-school time lessons> i...      2.0      1.0
# 231921  I do not attend <out-of-school time lessons> i...      7.0      0.0
# 377894                                                NaN      NaN      NaN
# 60778   I do not attend <out-of-school time lessons> i...      1.0      0.0
# 377184                           Less than 2 hours a week      2.0      NaN
# 21389   I do not attend <out-of-school time lessons> i...      4.0      2.0
# 216899                                                NaN      NaN      NaN
#
#         ST57Q03  ST57Q04  ST57Q05  ST57Q06     ST61Q01     ST61Q02  \
# 266178      NaN      NaN      1.0      1.0  Frequently   Sometimes
# 432641      NaN      NaN      NaN      NaN     Rarely    Sometimes
# 410269      0.0      0.0      0.0      0.0      Never       Never
# 18505       0.0      0.0      1.0      1.0      Never       Never
# 231921      0.0      0.0      0.0      0.0      Never      Rarely
# 377894      NaN      NaN      NaN      NaN         NaN         NaN
# 60778       0.0      0.0      0.0      1.0   Sometimes  Frequently
# 377184      2.0      5.0      2.0      1.0   Sometimes  Frequently
# 21389       0.0      0.0      0.0      3.0      Never       Never
# 216899      NaN      NaN      NaN      NaN         NaN         NaN
#
#            ST61Q03    ST61Q04     ST61Q05     ST61Q06     ST61Q07     ST61Q08  \
# 266178     Rarely         NaN   Sometimes   Sometimes  Frequently  Frequently
# 432641   Sometimes  Sometimes  Frequently   Sometimes  Frequently   Sometimes
# 410269     Rarely      Never    Sometimes     Rarely   Frequently     Rarely
# 18505    Sometimes  Sometimes  Frequently  Frequently  Frequently   Sometimes
# 231921     Rarely     Rarely   Frequently     Rarely   Frequently      Never
# 377894         NaN        NaN         NaN         NaN         NaN         NaN
# 60778      Rarely     Rarely      Rarely      Rarely      Rarely    Sometimes
# 377184  Frequently        NaN  Frequently  Frequently  Frequently   Sometimes
# 21389    Sometimes     Never   Frequently      Never   Frequently      Never
# 216899         NaN        NaN         NaN         NaN         NaN         NaN
#
#            ST61Q09                    ST62Q01  \
# 266178  Frequently  Heard of it once or twice
# 432641     Rarely   Heard of it once or twice
# 410269   Sometimes          Never heard of it
# 18505   Frequently          Never heard of it
# 231921  Frequently          Never heard of it
# 377894         NaN                        NaN
# 60778    Sometimes  Heard of it once or twice
# 377184  Frequently  Heard of it once or twice
# 21389   Frequently    Heard of it a few times
# 216899         NaN                        NaN
#
#                                       ST62Q02  \
# 266178                      Heard of it often
# 432641  Know it well,  understand the concept
# 410269  Know it well,  understand the concept
# 18505                       Heard of it often
# 231921                      Heard of it often
# 377894                                    NaN
# 60778   Know it well,  understand the concept
# 377184                Heard of it a few times
# 21389   Know it well,  understand the concept
# 216899                                    NaN
#
#                                       ST62Q03  \
# 266178                      Heard of it often
# 432641  Know it well,  understand the concept
# 410269              Heard of it once or twice
# 18505                       Heard of it often
# 231921  Know it well,  understand the concept
# 377894                                    NaN
# 60778                       Never heard of it
# 377184                      Never heard of it
# 21389                 Heard of it a few times
# 216899                                    NaN
#
#                                       ST62Q04  \
# 266178                      Heard of it often
# 432641  Know it well,  understand the concept
# 410269                Heard of it a few times
# 18505                       Heard of it often
# 231921                      Never heard of it
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184              Heard of it once or twice
# 21389   Know it well,  understand the concept
# 216899                                    NaN
#
#                                       ST62Q06  \
# 266178                Heard of it a few times
# 432641  Know it well,  understand the concept
# 410269  Know it well,  understand the concept
# 18505                       Heard of it often
# 231921  Know it well,  understand the concept
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184                Heard of it a few times
# 21389                       Never heard of it
# 216899                                    NaN
#
#                                       ST62Q07  \
# 266178                Heard of it a few times
# 432641  Know it well,  understand the concept
# 410269                      Heard of it often
# 18505                       Heard of it often
# 231921                      Never heard of it
# 377894                                    NaN
# 60778                       Never heard of it
# 377184                      Never heard of it
# 21389               Heard of it once or twice
# 216899                                    NaN
#
#                                       ST62Q08  \
# 266178  Know it well,  understand the concept
# 432641                      Heard of it often
# 410269                      Never heard of it
# 18505                       Heard of it often
# 231921                      Heard of it often
# 377894                                    NaN
# 60778                       Never heard of it
# 377184              Heard of it once or twice
# 21389               Heard of it once or twice
# 216899                                    NaN
#
#                                       ST62Q09  \
# 266178  Know it well,  understand the concept
# 432641  Know it well,  understand the concept
# 410269  Know it well,  understand the concept
# 18505                       Heard of it often
# 231921  Know it well,  understand the concept
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184                Heard of it a few times
# 21389                 Heard of it a few times
# 216899                                    NaN
#
#                                       ST62Q10  \
# 266178                      Heard of it often
# 432641  Know it well,  understand the concept
# 410269                      Heard of it often
# 18505                       Heard of it often
# 231921                Heard of it a few times
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184  Know it well,  understand the concept
# 21389                 Heard of it a few times
# 216899                                    NaN
#
#                                       ST62Q11  \
# 266178                                    NaN
# 432641                      Heard of it often
# 410269                      Never heard of it
# 18505                       Heard of it often
# 231921                      Never heard of it
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184  Know it well,  understand the concept
# 21389                       Never heard of it
# 216899                                    NaN
#
#                                       ST62Q12                    ST62Q13  \
# 266178                      Heard of it often                        NaN
# 432641  Know it well,  understand the concept          Heard of it often
# 410269  Know it well,  understand the concept          Never heard of it
# 18505                       Heard of it often          Heard of it often
# 231921                      Never heard of it          Never heard of it
# 377894                                    NaN                        NaN
# 60778                 Heard of it a few times          Never heard of it
# 377184  Know it well,  understand the concept  Heard of it once or twice
# 21389                 Heard of it a few times          Never heard of it
# 216899                                    NaN                        NaN
#
#                                       ST62Q15  \
# 266178                      Heard of it often
# 432641  Know it well,  understand the concept
# 410269  Know it well,  understand the concept
# 18505                       Heard of it often
# 231921              Heard of it once or twice
# 377894                                    NaN
# 60778                 Heard of it a few times
# 377184                Heard of it a few times
# 21389                       Never heard of it
# 216899                                    NaN
#
#                                       ST62Q16  \
# 266178                      Never heard of it
# 432641                      Heard of it often
# 410269                      Heard of it often
# 18505                       Heard of it often
# 231921  Know it well,  understand the concept
# 377894                                    NaN
# 60778                       Heard of it often
# 377184                      Never heard of it
# 21389                       Heard of it often
# 216899                                    NaN
#
#                                       ST62Q17  \
# 266178  Know it well,  understand the concept
# 432641  Know it well,  understand the concept
# 410269                      Never heard of it
# 18505                       Heard of it often
# 231921                Heard of it a few times
# 377894                                    NaN
# 60778                       Never heard of it
# 377184              Heard of it once or twice
# 21389                       Never heard of it
# 216899                                    NaN
#
#                                       ST62Q19  ST69Q01  ST69Q02  ST69Q03  \
# 266178                      Heard of it often      NaN      NaN      NaN
# 432641                      Heard of it often     45.0     45.0     45.0
# 410269  Know it well,  understand the concept     84.0     84.0     84.0
# 18505                       Heard of it often     60.0     60.0     60.0
# 231921  Know it well,  understand the concept     40.0     40.0     40.0
# 377894                                    NaN      NaN      NaN      NaN
# 60778                       Never heard of it     40.0     40.0     40.0
# 377184              Heard of it once or twice      NaN      NaN      NaN
# 21389                       Never heard of it    180.0    180.0    120.0
# 216899                                    NaN      NaN      NaN      NaN
#
#         ST70Q01  ST70Q02  ST70Q03  ST71Q01  ST72Q01     ST73Q01     ST73Q02  \
# 266178      NaN      5.0      4.0      NaN     18.0  Frequently  Frequently
# 432641      3.0      3.0      2.0     33.0     20.0   Sometimes   Sometimes
# 410269      3.0      3.0      3.0      NaN     25.0     Rarely   Frequently
# 18505       2.0      2.0      2.0      9.0      NaN  Frequently   Sometimes
# 231921      5.0      5.0      5.0     42.0     23.0     Rarely    Sometimes
# 377894      NaN      NaN      NaN      NaN      NaN         NaN         NaN
# 60778       4.0      4.0      NaN      NaN     30.0  Frequently     Rarely
# 377184      2.0      3.0      4.0     10.0     20.0  Frequently   Sometimes
# 21389       2.0      2.0      1.0     17.0     37.0      Never       Never
# 216899      NaN      NaN      NaN      NaN      NaN         NaN         NaN
#
#            ST74Q01     ST74Q02     ST75Q01     ST75Q02     ST76Q01  \
# 266178  Frequently  Frequently  Frequently  Frequently         NaN
# 432641   Sometimes   Sometimes   Sometimes   Sometimes   Sometimes
# 410269   Sometimes   Sometimes   Sometimes   Sometimes   Sometimes
# 18505   Frequently  Frequently  Frequently  Frequently  Frequently
# 231921   Sometimes  Frequently   Sometimes   Sometimes     Rarely
# 377894         NaN         NaN         NaN         NaN         NaN
# 60778    Sometimes   Sometimes   Sometimes     Rarely    Sometimes
# 377184     Rarely   Frequently  Frequently   Sometimes  Frequently
# 21389      Rarely      Rarely       Never       Never       Never
# 216899         NaN         NaN         NaN         NaN         NaN
#
#            ST76Q02       ST77Q01       ST77Q02       ST77Q04  \
# 266178         NaN  Most Lessons  Most Lessons  Every Lesson
# 432641   Sometimes           NaN           NaN           NaN
# 410269  Frequently  Every Lesson  Every Lesson  Every Lesson
# 18505    Sometimes           NaN           NaN           NaN
# 231921   Sometimes           NaN           NaN           NaN
# 377894         NaN           NaN           NaN           NaN
# 60778    Sometimes           NaN           NaN           NaN
# 377184   Sometimes           NaN           NaN           NaN
# 21389       Never            NaN           NaN           NaN
# 216899         NaN  Most Lessons  Most Lessons  Some Lessons
#
#                      ST77Q05       ST77Q06       ST79Q01       ST79Q02  \
# 266178          Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 432641                   NaN           NaN           NaN           NaN
# 410269          Every Lesson  Most Lessons  Every Lesson  Most Lessons
# 18505                    NaN           NaN           NaN           NaN
# 231921                   NaN           NaN           NaN           NaN
# 377894                   NaN           NaN           NaN           NaN
# 60778                    NaN           NaN           NaN           NaN
# 377184                   NaN           NaN           NaN           NaN
# 21389                    NaN           NaN  Some Lessons  Some Lessons
# 216899  Never or Hardly Ever  Some Lessons  Most Lessons  Most Lessons
#
#                      ST79Q03               ST79Q04               ST79Q05  \
# 266178          Most Lessons          Some Lessons          Some Lessons
# 432641                   NaN                   NaN                   NaN
# 410269  Never or Hardly Ever  Never or Hardly Ever          Every Lesson
# 18505                    NaN                   NaN                   NaN
# 231921                   NaN                   NaN                   NaN
# 377894                   NaN                   NaN                   NaN
# 60778                    NaN                   NaN                   NaN
# 377184                   NaN                   NaN                   NaN
# 21389           Some Lessons          Some Lessons          Some Lessons
# 216899  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
#
#              ST79Q06       ST79Q07       ST79Q08               ST79Q10  \
# 266178  Most Lessons  Most Lessons  Every Lesson          Some Lessons
# 432641           NaN           NaN           NaN                   NaN
# 410269  Every Lesson  Every Lesson  Some Lessons  Never or Hardly Ever
# 18505            NaN           NaN           NaN                   NaN
# 231921           NaN           NaN           NaN                   NaN
# 377894           NaN           NaN           NaN                   NaN
# 60778            NaN           NaN           NaN                   NaN
# 377184           NaN           NaN           NaN                   NaN
# 21389   Most Lessons  Some Lessons  Some Lessons  Never or Hardly Ever
# 216899  Most Lessons  Some Lessons  Some Lessons  Never or Hardly Ever
#
#                      ST79Q11       ST79Q12       ST79Q15  \
# 266178          Some Lessons  Most Lessons  Most Lessons
# 432641                   NaN           NaN           NaN
# 410269          Some Lessons  Every Lesson  Every Lesson
# 18505                    NaN           NaN           NaN
# 231921                   NaN           NaN           NaN
# 377894                   NaN           NaN           NaN
# 60778                    NaN           NaN           NaN
# 377184                   NaN           NaN           NaN
# 21389           Some Lessons  Some Lessons  Most Lessons
# 216899  Never or Hardly Ever  Some Lessons  Some Lessons
#
#                      ST79Q17          ST80Q01    ST80Q04          ST80Q05  \
# 266178          Most Lessons            Often  Sometimes        Sometimes
# 432641                   NaN              NaN        NaN              NaN
# 410269          Some Lessons            Often      Often            Often
# 18505                    NaN              NaN        NaN              NaN
# 231921                   NaN              NaN        NaN              NaN
# 377894                   NaN              NaN        NaN              NaN
# 60778                    NaN              NaN        NaN              NaN
# 377184                   NaN              NaN        NaN              NaN
# 21389           Some Lessons  Never or rarely  Sometimes  Never or rarely
# 216899  Never or Hardly Ever        Sometimes      Often        Sometimes
#
#                 ST80Q06          ST80Q07                  ST80Q08  \
# 266178        Sometimes            Often                    Often
# 432641              NaN              NaN                      NaN
# 410269        Sometimes            Often  Always or almost always
# 18505               NaN              NaN                      NaN
# 231921              NaN              NaN                      NaN
# 377894              NaN              NaN                      NaN
# 60778               NaN              NaN                      NaN
5.0805    5.0805    5.0805    5.0805    5.0805    5.0805    5.0805
# 377894  143.8540   42.1497   44.3433   45.8165   45.8416  143.7753  137.4495
# 60778    35.2462   12.2852   36.4800   36.4800   36.4800   35.2462   11.7853
# 377184   89.7488   29.9163   89.7488   89.7488   89.7488   89.7488   29.9163
# 21389   139.5719  139.5719   46.5240  139.5719   46.5240  139.5719   46.5240
# 216899   20.9889   20.9889    6.9963    6.9963    6.9963    6.9963   20.9889
#
#         W_FSTR80  WVARSTRR  VAR_UNIT  SENWGT_STU  VER_STU
# 266178    6.1954        14         2      0.0238  22NOV13
# 432641    5.9174        13         2      0.1767  22NOV13
# 410269   29.7151        66         1      0.4998  22NOV13
# 18505   102.3024        43         2      0.1242  22NOV13
# 231921    5.0805        25         1      0.1875  22NOV13
# 377894   42.1497        66         1      0.2147  22NOV13
# 60778    12.2852        35         1      0.0102  22NOV13
# 377184   29.9163        67         1      0.1425  22NOV13
# 21389    46.5240        72         1      0.1704  22NOV13
# 216899    6.9963        24         1      0.1535  22NOV13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Columns: 636 entries, Unnamed: 0 to VER_STU
# dtypes: float64(250), int64(18), object(368)
# memory usage: 2.3+ GB

# %%
df.shape
# Out:
# (485490, 636)

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The PISA dataset is a dataset with 636 columns and 495 489 rows.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > * **_Math, Science and Reading Score Distribution_**<br>
# > * **_Differences in scores between OECD and Non OECD countries_**<br>
# > * **_Differences in Scores between Girls and boys_**
# > * **_Computer time and the effects on scores_**
# > * **_Cognitive Activity development in OECD, Non_OECD Countries and between Gender_**
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
# The following features of the dataset will help get the response I need:
# ![image.png](attachment:image.png)

# %%
wanted_columns = ['CNT','OECD','ST01Q01','ST02Q01', 'ST04Q01','ST28Q01','ST53Q01','ST53Q02','ST80Q01','ST80Q04','ST80Q05',
                  'ST80Q06','ST80Q07', 'ST80Q08', 'ST80Q09', 'ST80Q10', 'ST80Q11','TIMEINT','PV1MATH','PV2MATH','PV3MATH',
                  'PV4MATH','PV5MATH', 'PV1READ', 'PV2READ', 'PV3READ', 'PV4READ',
                  'PV5READ', 'PV1SCIE', 'PV2SCIE','PV3SCIE', 'PV4SCIE','PV5SCIE']

# %%
df_selected = df[wanted_columns].copy()

# %%
df_selected.sample(5)
# Out:
#                   CNT      OECD  ST01Q01  ST02Q01 ST04Q01        ST28Q01  \
# 407560  Florida (USA)  Non-OECD       11      1.0  Female  26-100 books
# 376034           Peru  Non-OECD       10      1.0    Male  26-100 books
# 113357          Chile      OECD       10      2.0    Male    0-10 books
# 377762           Peru  Non-OECD       10      1.0  Female  26-100 books
# 471240        Uruguay  Non-OECD       10      7.0  Female  26-100 books
#
#                   ST53Q01                ST53Q02    ST80Q01  \
# 407560  relating to known  Improve understanding        NaN
# 376034     Most important               new ways  Sometimes
# 113357     Most important  Improve understanding        NaN
# 377762  relating to known           check memory      Often
# 471240                NaN                    NaN      Often
#
#                         ST80Q04                  ST80Q05  \
# 407560                      NaN                      NaN
# 376034                Sometimes                    Often
# 113357                      NaN                      NaN
# 377762  Always or almost always                    Often
# 471240                Sometimes  Always or almost always
#
#                         ST80Q06                  ST80Q07  \
# 407560                      NaN                      NaN
# 376034                Sometimes                    Often
# 113357                      NaN                      NaN
# 377762                    Often  Always or almost always
# 471240  Always or almost always  Always or almost always
#
#                         ST80Q08 ST80Q09                  ST80Q10  \
# 407560                      NaN     NaN                      NaN
# 376034                    Often   Often                Sometimes
# 113357                      NaN     NaN                      NaN
# 377762  Always or almost always   Often  Always or almost always
# 471240                Sometimes   Often                    Often
#
#                         ST80Q11  TIMEINT   PV1MATH   PV2MATH   PV3MATH  \
# 407560                      NaN      NaN  505.9277  611.8632  517.6118
# 376034                    Often      NaN  438.8612  387.4513  421.7246
# 113357                      NaN     58.0  491.5953  439.4064  476.0165
# 377762  Always or almost always      NaN  356.9949  406.0679  327.3952
# 471240  Always or almost always     71.0  463.7872  474.6923  463.7872
#
#          PV4MATH   PV5MATH   PV1READ   PV2READ   PV3READ   PV4READ   PV5READ  \
# 407560  562.0112  540.2010  545.2978  647.7638  568.3328  650.1468  581.0418
# 376034  408.4826  391.3460  420.2010  367.2726  404.1621  458.6943  453.0807
# 113357  483.0270  509.5108  477.0589  437.7636  458.6141  513.9483  468.2375
# 377762  278.3222  337.5214  441.7992  507.7270  407.6439  413.9984  424.3244
# 471240  415.4931  501.1762  514.0815  527.5847  534.7335  458.4797  535.5278
#
#          PV1SCIE   PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 407560  543.3980  626.3894  548.0604  604.9422  568.5752
# 376034  446.6990  485.8635  421.5218  425.2518  420.5893
# 113357  452.9467  438.0269  479.9888  520.0858  466.0015
# 377762  416.4864  368.9295  347.4823  338.1574  403.4316
# 471240  465.3488  491.4584  478.4036  422.4543  490.5259

# %%
# renaming the selected columns so that it is easier to understand
df_selected.rename(columns=
                   {'CNT':'country', 
                    'OECD':'OECD', 
                    'ST01Q01':'international_grade',
                    'ST02Q01':'national_study_program', 
                    'ST04Q01':'gender',
                    'ST28Q01':'number_books',
                    'ST53Q01':'Learning_strategies_1',
                    'ST53Q02':'Learning_strategies_2',
                    'ST80Q01':'CA_TeacherEncouragesToReflectProblems',
                    'ST80Q04':'CA_GivesProblemThatRequireToThink',
                    'ST80Q05':'CA_AsksToUseOwnProcedures',
                    'ST80Q06':'CA_PresentsProblemsWithNoObviousSolutions',
                    'ST80Q07':'CA_PresentsProblemsInDifferentContexts',
                    'ST80Q08':'CA_HelpsLearnFromMistakes',
                    'ST80Q09':'CA_AsksForExplanation',
                    'ST80Q10':'CA_ApplyWhatTheyLearned',
                    'ST80Q11':'CA_ProblemWithMultipleSolutions',
                    'TIMEINT':'Computer_time'}, inplace=True)

# %%
#checking if columns were renamed
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time   PV1MATH   PV2MATH  \
# 0                           Often            NaN  406.8469  376.4683
#
#     PV3MATH   PV4MATH   PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ  \
# 0  344.5319  321.1637  381.9209  249.5762  254.342  406.8496  175.7053
#
#     PV5READ   PV1SCIE  PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 0  218.5981  341.7009   408.84  348.2283  367.8105  392.9877

# %% [markdown]
# Each score is represented five time for each participants. so I am going to calculate an average value for each score, it will be easier to work with only one value.

# %%
df_selected['math_average'] =  (df_selected['PV1MATH'] + df_selected['PV2MATH']+ 
                                df_selected['PV3MATH'] + df_selected['PV4MATH'] + df_selected['PV5MATH'])/5
df_selected['reading_average'] = (df_selected ['PV1READ'] + df_selected['PV2READ']+ 
                          df_selected['PV3READ'] + df_selected ['PV4READ'] + df_selected['PV5READ'])/5
df_selected['science_average'] = (df_selected['PV1SCIE'] + df_selected ['PV2SCIE']+ 
                          df_selected['PV3SCIE'] + df_selected['PV4SCIE'] + df_selected['PV5SCIE'])/5

# %%
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time   PV1MATH   PV2MATH  \
# 0                           Often            NaN  406.8469  376.4683
#
#     PV3MATH   PV4MATH   PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ  \
# 0  344.5319  321.1637  381.9209  249.5762  254.342  406.8496  175.7053
#
#     PV5READ   PV1SCIE  PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE  math_average  \
# 0  218.5981  341.7009   408.84  348.2283  367.8105  392.9877     366.18634
#
#    reading_average  science_average
# 0        261.01424        371.91348

# %%
#since I no longoer need the individuals values for the dataframe, I am going to simply drop them
df_selected.drop(['PV1MATH', 'PV2MATH','PV3MATH', 'PV4MATH','PV5MATH','PV1READ','PV2READ','PV3READ','PV4READ','PV5READ', 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE'], axis=1, inplace=True)

# %%
df_selected.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time  math_average  \
# 0                           Often            NaN     366.18634
# 1                             NaN            NaN     470.56396
# 2                             NaN            NaN     505.53824
# 3                 Never or rarely            NaN     449.45476
# 4                           Often            NaN     385.50398
#
#    reading_average  science_average
# 0        261.01424        371.91348
# 1        384.68832        478.12382
# 2        405.18154        486.60946
# 3        477.46376        453.97240
# 4        256.01010        367.15778

# %%
# I am now going to save the new dataframe to a csv file so that is quicker to laod 
df_selected.to_csv('PISA_cognition.csv', encoding='utf-8', index=False)

# %%
df_cognition = pd.read_csv('PISA_cognition.csv', encoding='utf-8')
df_cognition.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time  math_average  \
# 0                           Often            NaN     366.18634
# 1                             NaN            NaN     470.56396
# 2                             NaN            NaN     505.53824
# 3                 Never or rarely            NaN     449.45476
# 4                           Often            NaN     385.50398
#
#    reading_average  science_average
# 0        261.01424        371.91348
# 1        384.68832        478.12382
# 2        405.18154        486.60946
# 3        477.46376        453.97240
# 4        256.01010        367.15778

# %%
df_cognition['math_average'].isnull().sum().sum(), df_cognition['reading_average'].isnull().sum().sum(), df_cognition['science_average'].isnull().sum().sum()
# Out:
# (0, 0, 0)

# %%
#sectioning the data in to 4 groups that I will need to use for later analysis(OECD, Non_OECD, female and male)
OECD = df_cognition.query('OECD == "OECD"')
Non_OECD = df_cognition.query('OECD=="Non-OECD"')
male= df_cognition.query('gender=="Male"')
female = df_cognition.query('gender=="Female"')
#verifying
OECD.shape[0], Non_OECD.shape[0], male.shape[0], female.shape[0]
# Out:
# (295416, 190074, 240426, 245064)

# %%
#checking null values in the computer time column, the non_OECD countries seem to be missing a lot of values. checking null values for female and male group
df_cognition['Computer_time'].isnull().sum().sum(), OECD['Computer_time'].isnull().sum().sum(), Non_OECD['Computer_time'].isnull().sum().sum(), female['Computer_time'].isnull().sum().sum(), male['Computer_time'].isnull().sum().sum()
# Out:
# (188416, 60938, 127478, 95416, 93000)

# %%
#replacing missing values by the mean for each group
#sub2['income'].fillna((sub2['income'].mean()), inplace=True)
OECD['Computer_time'].fillna((OECD['Computer_time'].mean()), inplace=True)
Non_OECD['Computer_time'].fillna((Non_OECD['Computer_time'].mean()), inplace=True)
female['Computer_time'].fillna((female['Computer_time'].mean()), inplace=True)
male['Computer_time'].fillna((male['Computer_time'].mean()), inplace=True)
# Out:
# C:\Users\gwiza\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#verifying if missing values were filled
OECD['Computer_time'].isnull().sum().sum(), Non_OECD['Computer_time'].isnull().sum().sum(), female['Computer_time'].isnull().sum().sum(), male['Computer_time'].isnull().sum().sum()
# Out:
# (0, 0, 0, 0)

# %% [markdown]
# ## Univariate Exploration
#
# > Now we are going to analyze the math, reading and science scores. we will also mostly try to understand th distributions scores. and the proportions of our group of interests, OECD, Non_OECD, boys and girls.

# %% [markdown]
# ## In general, Students Equally Succeed(or fail) in the field of Math, Reading and Science
# > My primary assumption would have been that students succeed more in one subject comparing to others. But I was pleased to see that based on this survey response, students tend to equally succeed (or fail) in all 3 subjects. The mean scores in Math, Reading and Science is the almost the same. the mode is is also very close to the mean and remain almost the same in all 3 subjects. <br>
# There is no subject where the average score is significantly higher or smaller than the others.
# It is important to quickly notice that the mean values are slightly below the average of 500. the test are scored on a 1000.

# %%
df_cognition['math_average'].mean(), df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()
# Out:
# (469.65123385442615, 472.0069640898506, 475.80809403002854)

# %%
#checking modes values to understand the most common  test scores
df_cognition['math_average'].mode(), df_cognition['reading_average'].mode(), df_cognition['science_average'].mode()
# Out:
# (0    479.36594
#  dtype: float64, 0    475.7957
#  dtype: float64, 0    475.88586
#  dtype: float64)

# %%
plt.figure(figsize=[6,5])
# plotting Math, Reading and Science Score to see if children tends to succeed more in one  
labels = ["Math Score", "Reading Score", "Science Score"]
usage = [df_cognition['math_average'].mean(),df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()]

# Generating the y positions. Later, we'll use them to replace them with labels.
y_positions = range(len(labels))

# Creating our bar plot
plt.bar(y_positions, usage)
plt.xticks(y_positions, labels)
plt.ylabel("Score")
plt.title("Average Scores in Math, Reading and Science")
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# ## Specifics Colors for each group
# In this analysis, I will be comparing OECD and Non OECD countries. And Female and Male Students. In order to make the charts easier to read, I will assign to each group a color that I will keep using all the way to the end of the analysis.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Proportions of OECD and Non OECD Countries that particapated in the survey
#
# As I was getting familiar with the dataset, It seemed interesting to know the proportions of OECD and Non_OECD Countries participants  in the survey. there are clearly much more OECD countries participants as they accounts for 60.8% of the survey's participants.

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['OECD'].value_counts()
colors = ['#008080', '#F4A460']
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',colors=colors,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# ## Proportion of Boys and Female Students in the survey
# The proportion of boys and girls who participated in the survey is almost equal

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['gender'].value_counts()
colors = ['#FF69B4','#1E90FF']
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',colors=colors,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# ## Scores Distribution for OECD and Non_OECD Countries

# %%
plt.figure(figsize = [20, 12])

bins_hist = np.arange(0, 1000 + 1, 100)
# 1st row  (OECD Countries)
plt.subplot(2, 3, 1)
color_OECD=['#008080']
color_NOECD = ['#F4A460']
xylabel = 13
title =16
plt.hist(OECD['math_average'], bins = bins_hist, alpha = 0.7, color=color_OECD);

plt.xticks(bins_hist)
plt.xlabel('Math Score Distribution',fontsize=xylabel);
plt.ylabel('Number of students',fontsize=xylabel)
plt.title("OECD Students", fontsize=title);

plt.subplot(2, 3, 2)
plt.hist(OECD['reading_average'], bins = bins_hist,  alpha = 0.7, color=color_OECD);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution',fontsize=xylabel);
plt.title("OECD Students",fontsize=14);

plt.subplot(2, 3, 3)
plt.hist(OECD['science_average'], bins = bins_hist, alpha = 0.7, color=color_OECD);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution',fontsize=xylabel);
plt.title("OECD Students",fontsize=title);

# 2nd row (Non OECD Countries)

plt.subplot(2, 3, 4)

plt.hist(Non_OECD['math_average'], bins = bins_hist, alpha = 0.7, color=color_NOECD);

plt.xticks(bins_hist)
plt.xlabel('Math Score Distribution',fontsize=xylabel);
plt.ylabel('Number of students',fontsize=xylabel)
plt.title("Non OECD Students", fontsize=title);

plt.subplot(2, 3, 5)
plt.hist(Non_OECD['reading_average'], bins = bins_hist,  alpha = 0.7, color=color_NOECD);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution',fontsize=xylabel);
plt.title("Non OECD Students",fontsize=title);

plt.subplot(2, 3, 6)
plt.hist(Non_OECD['science_average'], bins = bins_hist, alpha = 0.7, color=color_NOECD);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution',fontsize=xylabel);
plt.title("Non OECD Students",fontsize=title);

# %% [markdown]
# ## Scores Distribution for Girls and Boys

# %%
plt.figure(figsize = [20, 15])

bins_hist = np.arange(0, 1000 + 1, 100)
# 1st row  (OECD Countries)
plt.subplot(2, 3, 1)
color_girls= ['#FF69B4']
color_boys = ['#1E90FF']
alpha = 0.7
xylabel = 13
title =16
label = 'Female'
plt.hist(female['math_average'], bins = bins_hist, alpha = alpha, color=color_girls);
plt.hist(male['math_average'], bins = bins_hist, alpha = alpha, color=color_boys);

plt.xticks(bins_hist)
plt.ylabel('Number of students', fontsize=xylabel)
plt.title("Female & Male Students", fontsize=title);
plt.legend([ "Female", "Male"])

plt.xlabel('Math Score Distribution', fontsize=xylabel);
plt.subplot(2, 3, 2)
plt.hist(female['reading_average'], bins = bins_hist,  alpha = alpha, color=color_girls);
plt.hist(male['reading_average'], bins = bins_hist,  alpha = alpha, color=color_boys);
plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution', fontsize=xylabel);
plt.title("Female & Male Students", fontsize=title);
plt.legend([ "Female", "Male"])

plt.subplot(2, 3, 3)
plt.hist(female['science_average'], bins = bins_hist, alpha = alpha, color=color_girls);
plt.hist(male['science_average'], bins = bins_hist, alpha = alpha, color=color_boys);
plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution', fontsize=xylabel);
plt.title("Female & Male Students", fontsize=title);
plt.legend([ "Female", "Male"]);

# %% [markdown]
# ## Computer Time Distribution
#
# >We want to see the distribution of computer time in our groups. <br>
# In the next section, we look for a possible correlation between the time spent on computer and the scores

# %%
# fill missing values with 
OECD['Computer_time'].describe(), Non_OECD['Computer_time'].mode()
# Out:
# (count    295416.000000
#  mean         50.590772
#  std          36.243653
#  min           0.000000
#  25%          26.000000
#  50%          50.590772
#  75%          58.000000
#  max         206.000000
#  Name: Computer_time, dtype: float64, 0    52.039332
#  dtype: float64)

# %%
Non_OECD_PC = Non_OECD['Computer_time'].dropna()
Non_OECD_PC.count()
# Out:
# 190074

# %%
plt.figure(figsize = [20, 10])
color_OECD='#008080'
color_NOECD = '#F4A460'

bins_hist = np.arange(0,210, 10)
# 1st row  
plt.subplot(2, 2, 1)
ax = sb.boxplot(x=OECD['Computer_time'], color=color_OECD).set_title('OECD Countries')

plt.subplot(2, 2, 2)
ax = sb.boxplot(x=OECD['Computer_time'], color=color_NOECD).set_title('Non OECD Countries')

# %% [markdown]
# ## Computer Time, Boys and Girls

# %%
plt.figure(figsize = [15, 8])

color_girls= '#FF69B4'
color_boys = '#1E90FF'

bins_hist = np.arange(0,210, 10)#ax = sb.violinplot(x=male['Computer_time'], color=color_boys)
plt.hist(female['Computer_time'], bins = bins_hist, alpha = 0.7, color=color_girls);
plt.hist(male['Computer_time'], bins = bins_hist, alpha = 0.7, color=color_boys);
plt.xticks(bins_hist)
plt.xlabel('Time in Minutes');
plt.title("Students Computer time")
plt.legend(["Female", "Male"]);

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ## Cognitive Activity

# %%
df_cognition_copy = df_cognition.copy()

# %%
#df_likert= df_cognition.drop(['international_grade','national_study_program', 'number_books', 'Learning_strategies_1', 'Learning_strategies_2'], axis=1, inplace=True)
df_likert =df_cognition.copy()
df_likert.drop(['international_grade','national_study_program', 'number_books', 'Learning_strategies_1', 'Learning_strategies_2'], axis=1, inplace=True)

# %%
df_likert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Data columns (total 16 columns):
# country                                      485490 non-null object
# OECD                                         485490 non-null object
# gender                                       485490 non-null object
# CA_TeacherEncouragesToReflectProblems        314171 non-null object
# CA_GivesProblemThatRequireToThink            313521 non-null object
# CA_AsksToUseOwnProcedures                    312593 non-null object
# CA_PresentsProblemsWithNoObviousSolutions    312490 non-null object
# CA_PresentsProblemsInDifferentContexts       312521 non-null object
# CA_HelpsLearnFromMistakes                    312591 non-null object
# CA_AsksForExplanation                        311814 non-null object
# CA_ApplyWhatTheyLearned                      312305 non-null object
# CA_ProblemWithMultipleSolutions              312865 non-null object
# Computer_time                                297074 non-null float64
# math_average                                 485490 non-null float64
# reading_average                              485490 non-null float64
# science_average                              485490 non-null float64
# dtypes: float64(4), object(12)
# memory usage: 59.3+ MB

# %%
def unique_values(df, var_list):
     for var in var_list:
         print(var, ' Unique Values:\n', df[var].unique(), '\n')
unique_values(df_likert, df_likert.columns.tolist())
# Out:
# country  Unique Values:
#  ['Albania' 'United Arab Emirates' 'Argentina' 'Australia' 'Austria'
#  'Belgium' 'Bulgaria' 'Brazil' 'Canada' 'Switzerland' 'Chile' 'Colombia'
#  'Costa Rica' 'Czech Republic' 'Germany' 'Denmark' 'Spain' 'Estonia'
#  'Finland' 'France' 'United Kingdom' 'Greece' 'Hong Kong-China' 'Croatia'
#  'Hungary' 'Indonesia' 'Ireland' 'Iceland' 'Israel' 'Italy' 'Jordan'
#  'Japan' 'Kazakhstan' 'Korea' 'Liechtenstein' 'Lithuania' 'Luxembourg'
#  'Latvia' 'Macao-China' 'Mexico' 'Montenegro' 'Malaysia' 'Netherlands'
#  'Norway' 'New Zealand' 'Peru' 'Poland' 'Portugal' 'Qatar'
#  'China-Shanghai' 'Perm(Russian Federation)' 'Florida (USA)'
#  'Connecticut (USA)' 'Massachusetts (USA)' 'Romania' 'Russian Federation'
#  'Singapore' 'Serbia' 'Slovak Republic' 'Slovenia' 'Sweden'
#  'Chinese Taipei' 'Thailand' 'Tunisia' 'Turkey' 'Uruguay'
#  'United States of America' 'Vietnam']
#
# OECD  Unique Values:
#  ['Non-OECD' 'OECD']
#
# gender  Unique Values:
#  ['Female' 'Male']
#
# CA_TeacherEncouragesToReflectProblems  Unique Values:
#  ['Always or almost always' nan 'Never or rarely' 'Often' 'Sometimes']
#
# CA_GivesProblemThatRequireToThink  Unique Values:
#  ['Sometimes' nan 'Often' 'Always or almost always' 'Never or rarely']
#
# CA_AsksToUseOwnProcedures  Unique Values:
#  ['Never or rarely' nan 'Sometimes' 'Often' 'Always or almost always']
#
# CA_PresentsProblemsWithNoObviousSolutions  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_PresentsProblemsInDifferentContexts  Unique Values:
#  ['Always or almost always' nan 'Often' 'Never or rarely' 'Sometimes']
#
# CA_HelpsLearnFromMistakes  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_AsksForExplanation  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_ApplyWhatTheyLearned  Unique Values:
#  ['Often' nan 'Always or almost always' 'Sometimes' 'Never or rarely']
#
# CA_ProblemWithMultipleSolutions  Unique Values:
#  ['Often' nan 'Never or rarely' 'Always or almost always' 'Sometimes']
#
# Computer_time  Unique Values:
#  [ nan  32.  92. 163.  81.  54.  39.  45. 111.  41. 124.  28.  26.  94.
#   11.  58.  64.  88.  51. 154.  99.  77. 114.  71.   2. 139.  86.  13.
#   75.  62.  69. 118. 206. 144.   6.  15. 150.  19. 137. 101.  21.  43.
#   96.  17.  34. 120. 107. 180. 129.   9.  84.  73.  30.  47.   4.   0.
#   56.  49.]
#
# math_average  Unique Values:
#  [366.18634 470.56396 505.53824 ... 681.73392 667.86884 472.90076]
#
# reading_average  Unique Values:
#  [261.01424 384.68832 405.18154 ... 663.02994 565.07616 525.57658]
#
# science_average  Unique Values:
#  [371.91348 478.12382 486.60946 ... 743.3234  758.24318 513.83816]

# %%
#df.pivot(index='date', columns='variable', values='value')
df_likert.groupby('China')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-30cb1f7799ad> in <module>()
#       1 #df.pivot(index='date', columns='variable', values='value')
# ----> 2 df_likert.groupby('China')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'China'

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!

# %% [markdown]
# ## References:
# * PISA 2012 contest winner: http://mi2.mini.pw.edu.pl:8080/SmarterPoland/PISAcontest/
# * What is PISA: http://www.oecd.org/pisa/
# * OECD: https://en.wikipedia.org/wiki/OECD
# * PISA 2012 Countries : http://www.oecd.org/pisa/aboutpisa/pisa-2012-participants.htm
# * PISA 2012 Data analysis Manual:http://archivos.agenciaeducacion.cl/Manual_de_Analisis_de_datos_SPSS_version_ingles.pdf
# * PISA Data Exploration : https://github.com/brunoassisp/PISA-Data-Viz-project/blob/master/PISA_EDA.ipynb
# * Jasccyang github repository : https://github.com/jasccyang/PISA2012/blob/master/Reducing%20File%20Size.ipynb
# * Seby Sbirna Github repository: https://github.com/seby-sbirna/Data-Analyst-Nanodegree-Project-Portfolio/blob/master/Project%205%20-%20Communicate%20Data%20Findings/Project%205%20-%20Sebastian%20Sbirna.ipynb
# * Visualization: https://www.researchgate.net/figure/Responses-to-Relating-to-your-last-five-publications-how-often-did-you-incorporate-the_fig1_328394497
# * Udacity Classroom: https://classroom.udacity.com/nanodegrees/nd002/parts/9f7e8991-8bfb-4103-8307-3b6f93f0ecc7
# * BarPlot with matplotlib: https://towardsdatascience.com/data-science-with-python-intro-to-data-visualization-and-matplotlib-5f799b7c6d82
# * Pivot table: https://www.dataquest.io/blog/pandas-pivot-table
# * Pandas stack:https://stackoverflow.com/questions/49098380/pandas-condense-survey-results
# * Reshaping Dataframe: https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
# * colors: https://www.rapidtables.com/web/color/RGB_Color.html
