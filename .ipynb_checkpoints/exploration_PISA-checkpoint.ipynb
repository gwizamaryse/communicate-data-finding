# %% [markdown]
# # PISA 2012 Dataset Exploration
# ## by Maryse Bonhomme
#
# ## Preliminary Wrangling
#
# > PISA is the [OECD's](https://en.wikipedia.org/wiki/OECD) Program for International Students Assessment. The goal of the Program is to assess 15 years old in order to evaluate their skills in Math, Reading and Science. And more importantly to evaluate how prepared to the future they are by asking all sort of questions.
# The Survey is done by PISA every 3 years, and assess various areas of the 15 years old. They assess the students life both inside school and out of school, including at home. Asking questions about possessions, family context and even how much mental stimulation the students get (cognitive activity).<p>The dataset that will be used today for analysis is the PISA 2012 survey, with participants from 65 countries.we are using the responses the survey.
# The results is a huge dataset with more than 636  variables and responses from almost 510, 000 students ( 485490 rows are part of this dataset).

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("darkgrid")

# %matplotlib inline

# %% [markdown]
# > The dataset covers a broad areas of the 15 years old. As part of the analysis today, I will focus  on the following questions:
# * In which Subject are students getting better scores?
# * Do OECD and Non_OECD perform in the tests?
# * On Math, Reading and Science tests, do boys and girls perform the same? is the score distribution the same?
# * How does the time spent on computer affect students scores? does it even have any impact on the students?
# * which countries have the biggest computer users?
# * Do boys and girls spend as much time on the computer? is there a difference between OECD and Non_OECD countries?
# * since in real life, the ability to adapt to new context is crucial, I was very interested in the cognitive activation section of the survey. Are children most encouraged to find to think on their own, are given the freedom to explore different ways of finding answers?  <br>
# * are there differences in the perception about cognitive activation between genders?
# * Are the trends the same in  OECD and Non_OECD Countries?

# %%
#loading the dataset
pd.set_option('display.max_columns', None)
df = pd.read_csv('pisa2012.csv',encoding='cp1252')
# Out:
# C:\Users\gwiza\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# using panda's sample to visually check the data
df.sample(10)
# Out:
#         Unnamed: 0                       CNT  SUBNATIO  STRATUM      OECD  \
# 467873      467874                    Turkey   7920000  TUR0003      OECD
# 115389      115390                  Colombia   1700000  COL0606  Non-OECD
# 166651      166652                     Spain   7240300  ESP0305      OECD
# 298256      298257                 Lithuania   4400000  LTU0011  Non-OECD
# 17179        17180                 Argentina    320000  ARG0004  Non-OECD
# 191531      191532            United Kingdom   8260000  GBR1315      OECD
# 405453      405454  Perm(Russian Federation)   6430059  QRS0059  Non-OECD
# 142977      142978                   Denmark   2080000  DNK0001      OECD
# 428595      428596                    Serbia   6880000  SRB0004  Non-OECD
# 416194      416195                   Romania   6420000  ROU0002  Non-OECD
#
#                                      NC  SCHOOLID  STIDSTD  ST01Q01  ST02Q01  \
# 467873                          Turkey         90     2484       11      9.0
# 115389                        Colombia         51     1291       10      2.0
# 166651                            Spain       755    21069       10      1.0
# 298256                        Lithuania        93     2071        9      4.0
# 17179                         Argentina        32      937       11      5.0
# 191531  United Kingdom (excl.Scotland)         98     2415       11      1.0
# 405453        Perm (Russian Federation)         2       60        9      1.0
# 142977                          Denmark       225     4876        9      1.0
# 428595                          Serbia         10      274        9      6.0
# 416194                          Romania       132     3724        9      2.0
#
#         ST03Q01  ST03Q02 ST04Q01                      ST05Q01  ST06Q01  \
# 467873        1     1996  Female                         No        6.0
# 115389        9     1996  Female  Yes, for more than one year      6.0
# 166651        7     1996  Female  Yes, for more than one year      5.0
# 298256        4     1996  Female  Yes, for more than one year      7.0
# 17179         7     1996    Male  Yes, for more than one year      6.0
# 191531       11     1996    Male   Yes, for one year or less       5.0
# 405453        5     1996    Male  Yes, for more than one year      6.0
# 142977        4     1996  Female  Yes, for more than one year      7.0
# 428595        3     1996    Male  Yes, for more than one year      7.0
# 416194        6     1996    Male  Yes, for more than one year      7.0
#
#           ST07Q01    ST07Q02    ST07Q03                ST08Q01  \
# 467873  No, never        NaN  No, never                 None
# 115389  No, never  No, never  No, never                 None
# 166651  No, never  No, never        NaN  Three or four times
# 298256  No, never  No, never        NaN     One or two times
# 17179   No, never  No, never  No, never     One or two times
# 191531  No, never  No, never  No, never                 None
# 405453  No, never  No, never        NaN  Three or four times
# 142977  No, never  No, never  No, never                 None
# 428595  No, never  No, never  No, never                 None
# 416194  No, never  No, never        NaN     One or two times
#
#                       ST09Q01  ST115Q01 ST11Q01 ST11Q02 ST11Q03 ST11Q04  \
# 467873  Three or four times         1.0     Yes     Yes     Yes     Yes
# 115389                 None         1.0     Yes     Yes     Yes      No
# 166651                 None         2.0     Yes     Yes     NaN     NaN
# 298256                 None         1.0     Yes     Yes      No      No
# 17179      One or two times         2.0     Yes     Yes     Yes      No
# 191531     One or two times         1.0     Yes     Yes     Yes     Yes
# 405453  Three or four times         2.0     Yes     NaN     NaN     NaN
# 142977                 None         1.0     Yes     Yes     NaN     Yes
# 428595                 None         1.0     Yes     Yes     NaN     NaN
# 416194                 None         2.0     Yes     Yes     NaN     Yes
#
#        ST11Q05 ST11Q06                ST13Q01 ST14Q01 ST14Q02 ST14Q03 ST14Q04  \
# 467873     Yes     NaN       <ISCED level 1>       No      No      No     NaN
# 115389      No      No      <ISCED level 3A>      Yes     Yes     Yes     NaN
# 166651     NaN     NaN      <ISCED level 3A>      NaN     NaN     Yes     NaN
# 298256      No      No  <ISCED level 3B, 3C>       No      No      No      No
# 17179       No      No      <ISCED level 3A>      Yes     Yes     Yes     NaN
# 191531      No      No  <ISCED level 3B, 3C>      Yes      No      No      No
# 405453     NaN     NaN      <ISCED level 3A>       No      No      No      No
# 142977     NaN     NaN      <ISCED level 3A>      NaN     NaN     Yes     NaN
# 428595     Yes     NaN  <ISCED level 3B, 3C>       No      No     Yes     NaN
# 416194     NaN     NaN      <ISCED level 3A>       No      No      No      No
#
#                                    ST15Q01                ST17Q01 ST18Q01  \
# 467873  Other (e.g. home duties, retired)        <ISCED level 1>       No
# 115389        Working full-time <for pay>       <ISCED level 3A>      NaN
# 166651        Working full-time <for pay>        <ISCED level 2>      NaN
# 298256         Working part-time <for pay>      <ISCED level 3A>       No
# 17179   Other (e.g. home duties, retired)       <ISCED level 3A>      Yes
# 191531         Working part-time <for pay>  <ISCED level 3B, 3C>       No
# 405453        Working full-time <for pay>   <ISCED level 3B, 3C>      Yes
# 142977        Working full-time <for pay>       <ISCED level 3A>      NaN
# 428595        Working full-time <for pay>   <ISCED level 3B, 3C>       No
# 416194        Working full-time <for pay>       <ISCED level 3A>       No
#
#        ST18Q02 ST18Q03 ST18Q04                             ST19Q01  \
# 467873      No      No     NaN        Working full-time <for pay>
# 115389     Yes     Yes     NaN  Other (e.g. home duties, retired)
# 166651     NaN     NaN     NaN        Working full-time <for pay>
# 298256      No     Yes      No        Working full-time <for pay>
# 17179      Yes     Yes     NaN  Not working, but looking for a job
# 191531      No      No      No        Working full-time <for pay>
# 405453     NaN     NaN     NaN        Working full-time <for pay>
# 142977     NaN     Yes     NaN        Working full-time <for pay>
# 428595      No      No     NaN        Working full-time <for pay>
# 416194      No      No     Yes        Working full-time <for pay>
#
#                 ST20Q01          ST20Q02          ST20Q03  ST21Q01  \
# 467873  Country of test  Country of test  Country of test      NaN
# 115389  Country of test  Country of test  Country of test      NaN
# 166651  Country of test  Country of test  Country of test      NaN
# 298256              NaN  Country of test  Country of test      NaN
# 17179   Country of test  Country of test  Country of test      NaN
# 191531  Country of test  Country of test  Country of test      NaN
# 405453  Country of test  Country of test  Country of test      NaN
# 142977  Country of test  Country of test  Country of test      NaN
# 428595  Country of test  Country of test  Country of test      NaN
# 416194  Country of test  Country of test  Country of test      NaN
#
#                      ST25Q01 ST26Q01 ST26Q02 ST26Q03 ST26Q04 ST26Q05 ST26Q06  \
# 467873  Language of the test     Yes      No      No     Yes      No      No
# 115389  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 166651  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 298256                   NaN     Yes     Yes     Yes     Yes     Yes     Yes
# 17179   Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 191531        Other language     Yes     Yes     Yes     Yes     Yes     Yes
# 405453  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 142977  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 428595  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 416194  Language of the test     Yes     Yes     Yes     Yes      No     Yes
#
#        ST26Q07 ST26Q08 ST26Q09 ST26Q10 ST26Q11 ST26Q12 ST26Q13 ST26Q14  \
# 467873      No      No      No     Yes     Yes     Yes     Yes      No
# 115389     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes
# 166651      No      No      No      No      No     Yes     Yes     Yes
# 298256     Yes      No     Yes     Yes     Yes     Yes      No     Yes
# 17179      Yes     Yes      No     Yes      No     Yes     Yes     Yes
# 191531     Yes     Yes      No     Yes     Yes     Yes     Yes     Yes
# 405453      No      No      No     Yes     Yes     Yes      No     Yes
# 142977     Yes      No      No     Yes      No     Yes     Yes     Yes
# 428595      No     Yes     Yes     Yes     Yes     Yes     Yes     Yes
# 416194     Yes     Yes      No     Yes     Yes     Yes      No     Yes
#
#         ST26Q15  ST26Q16  ST26Q17        ST27Q01        ST27Q02  \
# 467873   792002   792002   792002  Three or more            One
# 115389   170001   170001   170001  Three or more  Three or more
# 166651   724001   724001   724001  Three or more  Three or more
# 298256   440001   440001   440001  Three or more            Two
# 17179     32001    32002    32001  Three or more            Two
# 191531   826101   826101   826101  Three or more  Three or more
# 405453   643011   643012   643011  Three or more  Three or more
# 142977   208002   208001   208002  Three or more  Three or more
# 428595   688002   688002   688001            One            Two
# 416194   642001   642002   642002  Three or more  Three or more
#
#               ST27Q03 ST27Q04        ST27Q05              ST28Q01  \
# 467873            One    None           None        26-100 books
# 115389  Three or more     Two  Three or more       101-200 books
# 166651            Two     Two            Two          0-10 books
# 298256            Two     Two            One       201-500 books
# 17179             One     One            Two        26-100 books
# 191531  Three or more     Two            One       101-200 books
# 405453            One    None            One          0-10 books
# 142977  Three or more     One            One       101-200 books
# 428595            One     One            Two         11-25 books
# 416194            One     Two            One  More than 500 books
#
#                   ST29Q01            ST29Q02            ST29Q03  \
# 191531             Likely             Likely  Not at all likely
# 405453             Likely      Very   Likely  Not at all likely
# 142977  Not at all likely             Likely    Slightly likely
# 428595                NaN                NaN                NaN
# 416194             Likely  Not at all likely    Slightly likely
#
#                   ST44Q08         ST46Q01         ST46Q02            ST46Q03  \
# 467873  Not at all likely           Agree        Disagree     Strongly agree
# 115389                NaN             NaN             NaN                NaN
# 166651                NaN             NaN             NaN                NaN
# 298256      Very   Likely  Strongly agree  Strongly agree  Strongly disagree
# 17179       Very   Likely        Disagree           Agree              Agree
# 191531      Very   Likely  Strongly agree  Strongly agree              Agree
# 405453             Likely        Disagree           Agree     Strongly agree
# 142977    Slightly likely           Agree        Disagree              Agree
# 428595                NaN             NaN             NaN                NaN
# 416194      Very   Likely  Strongly agree        Disagree           Disagree
#
#                   ST46Q04         ST46Q05         ST46Q06         ST46Q07  \
# 467873     Strongly agree  Strongly agree           Agree           Agree
# 115389                NaN             NaN             NaN             NaN
# 166651                NaN             NaN             NaN             NaN
# 298256     Strongly agree           Agree  Strongly agree  Strongly agree
# 17179      Strongly agree           Agree           Agree           Agree
# 191531              Agree        Disagree           Agree           Agree
# 405453              Agree  Strongly agree  Strongly agree  Strongly agree
# 142977              Agree        Disagree           Agree             NaN
# 428595                NaN             NaN             NaN             NaN
# 416194  Strongly disagree  Strongly agree           Agree           Agree
#
#                ST46Q08         ST46Q09                             ST48Q01  \
# 467873           Agree  Strongly agree           Courses after school Math
# 115389             NaN             NaN                                 NaN
# 166651             NaN             NaN                                 NaN
# 298256  Strongly agree  Strongly agree           Courses after school Math
# 17179   Strongly agree        Disagree           Courses after school Math
# 191531        Disagree  Strongly agree  Courses after school Test Language
# 405453           Agree           Agree  Courses after school Test Language
# 142977           Agree             NaN  Courses after school Test Language
# 428595             NaN             NaN                                 NaN
# 416194        Disagree  Strongly agree           Courses after school Math
#
#                          ST48Q02                     ST48Q03  \
# 467873     Major in college Math           Study harder Math
# 115389                       NaN                         NaN
# 166651                       NaN                         NaN
# 298256  Major in college Science           Study harder Math
# 17179      Major in college Math           Study harder Math
# 191531  Major in college Science  Study harder Test Language
# 405453  Major in college Science  Study harder Test Language
# 142977     Major in college Math           Study harder Math
# 428595                       NaN                         NaN
# 416194     Major in college Math           Study harder Math
#
#                         ST48Q04                    ST48Q05  \
# 467873     Maximum classes Math     Pursuing a career Math
# 115389                      NaN                        NaN
# 166651                      NaN                        NaN
# 298256                      NaN  Pursuing a career Science
# 17179      Maximum classes Math     Pursuing a career Math
# 191531     Maximum classes Math  Pursuing a career Science
# 405453  Maximum classes Science     Pursuing a career Math
# 142977                      NaN     Pursuing a career Math
# 428595                      NaN                        NaN
# 416194     Maximum classes Math     Pursuing a career Math
#
#                         ST49Q01                  ST49Q02  \
# 467873                Sometimes                    Often
# 115389                      NaN                      NaN
# 166651                      NaN                      NaN
# 298256                Sometimes                    Often
# 17179           Never or rarely                Sometimes
# 191531                Sometimes                Sometimes
# 405453  Always or almost always                    Often
# 142977                    Often                    Often
# 428595                      NaN                      NaN
# 416194                    Often  Always or almost always
#
#                         ST49Q03                  ST49Q04          ST49Q05  \
# 467873                Sometimes          Never or rarely  Never or rarely
# 115389                      NaN                      NaN              NaN
# 166651                      NaN                      NaN              NaN
# 298256                    Often          Never or rarely        Sometimes
# 17179                     Often          Never or rarely            Often
# 191531          Never or rarely          Never or rarely  Never or rarely
# 405453  Always or almost always  Always or almost always            Often
# 142977                Sometimes          Never or rarely  Never or rarely
# 428595                      NaN                      NaN              NaN
# 416194                Sometimes  Always or almost always  Never or rarely
#
#                         ST49Q06                  ST49Q07          ST49Q09  \
# 467873          Never or rarely  Always or almost always  Never or rarely
# 115389                      NaN                      NaN              NaN
# 166651                      NaN                      NaN              NaN
# 298256          Never or rarely                    Often  Never or rarely
# 17179   Always or almost always          Never or rarely  Never or rarely
# 191531          Never or rarely          Never or rarely  Never or rarely
# 405453                    Often                    Often        Sometimes
# 142977          Never or rarely          Never or rarely  Never or rarely
# 428595                      NaN                      NaN              NaN
# 416194          Never or rarely  Always or almost always            Often
#
#                   ST53Q01                ST53Q02                     ST53Q03  \
# 467873     Most important  Improve understanding              learning goals
# 115389     Most important           check memory                 in my sleep
# 166651  relating to known  Improve understanding                 in my sleep
# 298256     Most important           check memory              learning goals
# 17179   relating to known  Improve understanding              learning goals
# 191531                NaN                    NaN                         NaN
# 405453  relating to known  Improve understanding  Relating to other subjects
# 142977           by heart  Improve understanding              learning goals
# 428595     Most important               new ways                 in my sleep
# 416194  relating to known               new ways  Relating to other subjects
#
#                  ST53Q04                                            ST55Q01  \
# 467873   Repeat examples                                                NaN
# 115389  more information             2 or more but less than 4 hours a week
# 166651     everyday life             2 or more but less than 4 hours a week
# 298256   Repeat examples  I do not attend <out-of-school time lessons> i...
# 17179    Repeat examples                           Less than 2 hours a week
# 191531               NaN                                                NaN
# 405453     everyday life  I do not attend <out-of-school time lessons> i...
# 142977   Repeat examples  I do not attend <out-of-school time lessons> i...
# 428595   Repeat examples  I do not attend <out-of-school time lessons> i...
# 416194  more information  I do not attend <out-of-school time lessons> i...
#
#                                                   ST55Q02  \
# 467873                             6 or more hours a week
# 115389             2 or more but less than 4 hours a week
# 166651                             6 or more hours a week
# 298256                           Less than 2 hours a week
# 17179              2 or more but less than 4 hours a week
# 191531                                                NaN
# 405453                           Less than 2 hours a week
# 142977  I do not attend <out-of-school time lessons> i...
# 428595  I do not attend <out-of-school time lessons> i...
# 416194                           Less than 2 hours a week
#
#                                                   ST55Q03  \
# 467873                             6 or more hours a week
# 115389             4 or more but less than 6 hours a week
# 166651             2 or more but less than 4 hours a week
# 298256  I do not attend <out-of-school time lessons> i...
# 17179   I do not attend <out-of-school time lessons> i...
# 191531                                                NaN
# 405453                           Less than 2 hours a week
# 142977  I do not attend <out-of-school time lessons> i...
# 428595  I do not attend <out-of-school time lessons> i...
# 416194  I do not attend <out-of-school time lessons> i...
#
#                                                   ST55
#
#                                       ST62Q06  \
# 467873                      Heard of it often
# 115389  Know it well,  understand the concept
# 166651                Heard of it a few times
# 298256              Heard of it once or twice
# 17179                       Never heard of it
# 191531                                    NaN
# 405453                      Never heard of it
# 142977                Heard of it a few times
# 428595  Know it well,  understand the concept
# 416194  Know it well,  understand the concept
#
#                                       ST62Q07  \
# 467873                      Heard of it often
# 115389                      Heard of it often
# 166651                Heard of it a few times
# 298256                      Never heard of it
# 17179                       Never heard of it
# 191531                                    NaN
# 405453                      Never heard of it
# 142977                      Never heard of it
# 428595              Heard of it once or twice
# 416194  Know it well,  understand the concept
#
#                                       ST62Q08  \
# 467873                      Heard of it often
# 115389              Heard of it once or twice
# 166651                Heard of it a few times
# 298256              Heard of it once or twice
# 17179               Heard of it once or twice
# 191531                                    NaN
# 405453                      Never heard of it
# 142977                      Never heard of it
# 428595  Know it well,  understand the concept
# 416194  Know it well,  understand the concept
#
#                                       ST62Q09  \
# 467873                      Heard of it often
# 115389  Know it well,  understand the concept
# 166651                                    NaN
# 298256  Know it well,  understand the concept
# 17179               Heard of it once or twice
# 191531                                    NaN
# 405453              Heard of it once or twice
# 142977                      Never heard of it
# 428595  Know it well,  understand the concept
# 416194  Know it well,  understand the concept
#
#                                       ST62Q10  \
# 467873                      Heard of it often
# 115389  Know it well,  understand the concept
# 166651                      Never heard of it
# 298256  Know it well,  understand the concept
# 17179               Heard of it once or twice
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                      Heard of it often
# 428595  Know it well,  understand the concept
# 416194  Know it well,  understand the concept
#
#                                       ST62Q11  \
# 467873                      Heard of it often
# 115389                      Never heard of it
# 166651                      Never heard of it
# 298256                      Never heard of it
# 17179   Know it well,  understand the concept
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                      Never heard of it
# 428595  Know it well,  understand the concept
# 416194                      Never heard of it
#
#                                       ST62Q12  \
# 467873                      Never heard of it
# 115389  Know it well,  understand the concept
# 166651                                    NaN
# 298256  Know it well,  understand the concept
# 17179                 Heard of it a few times
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                      Never heard of it
# 428595                                    NaN
# 416194  Know it well,  understand the concept
#
#                                       ST62Q13  \
# 467873  Know it well,  understand the concept
# 115389                      Never heard of it
# 166651              Heard of it once or twice
# 298256                      Never heard of it
# 17179   Know it well,  understand the concept
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                      Never heard of it
# 428595                      Never heard of it
# 416194                      Never heard of it
#
#                                       ST62Q15  \
# 467873                      Never heard of it
# 115389                      Never heard of it
# 166651              Heard of it once or twice
# 298256                Heard of it a few times
# 17179   Know it well,  understand the concept
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                      Never heard of it
# 428595                      Never heard of it
# 416194  Know it well,  understand the concept
#
#                                       ST62Q16  \
# 467873                      Never heard of it
# 115389  Know it well,  understand the concept
# 166651                      Never heard of it
# 298256              Heard of it once or twice
# 17179                       Never heard of it
# 191531                                    NaN
# 405453                Heard of it a few times
# 142977                Heard of it a few times
# 428595                      Never heard of it


# %% [markdown]
# ### What is the structure of your dataset?
#
# > The PISA dataset is a dataset with 636 columns and 495 489 rows.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > * **_Math, Science and Reading Score Distribution_**<br>
# > * **_Differences in scores between OECD and Non OECD countries_**<br>
# > * **_Differences in Scores between Girls and boys_**
# > * **_Computer time and the effects on scores_**
# > * **_Cognitive Activity development in OECD, Non_OECD Countries and between Gender_**
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
# The following features of the dataset will help get the response I need:
# ![image.png](attachment:image.png)

# %%
wanted_columns = ['CNT','OECD','ST01Q01','ST02Q01', 'ST04Q01','ST28Q01','ST53Q01','ST53Q02','ST80Q01','ST80Q04','ST80Q05',
                  'ST80Q06','ST80Q07', 'ST80Q08', 'ST80Q09', 'ST80Q10', 'ST80Q11','TIMEINT','PV1MATH','PV2MATH','PV3MATH',
                  'PV4MATH','PV5MATH', 'PV1READ', 'PV2READ', 'PV3READ', 'PV4READ',
                  'PV5READ', 'PV1SCIE', 'PV2SCIE','PV3SCIE', 'PV4SCIE','PV5SCIE']

# %%
df_selected = df[wanted_columns].copy()

# %%
df_selected.sample(5)
# Out:
#                    CNT      OECD  ST01Q01  ST02Q01 ST04Q01         ST28Q01  \
# 330800          Mexico      OECD       10      5.0  Female   26-100 books
# 192053  United Kingdom      OECD       12      1.0  Female    11-25 books
# 272843          Jordan  Non-OECD       10      1.0    Male    11-25 books
# 59988           Brazil  Non-OECD        8      1.0    Male  101-200 books
# 301459      Luxembourg      OECD        9      3.0    Male   26-100 books
#
#                ST53Q01                ST53Q02                  ST80Q01  \
# 330800  Most important  Improve understanding          Never or rarely
# 192053        by heart           check memory                    Often
# 272843  Most important  Improve understanding  Always or almost always
# 59988              NaN                    NaN  Always or almost always
# 301459             NaN                    NaN  Always or almost always
#
#                         ST80Q04                  ST80Q05  \
# 330800  Always or almost always          Never or rarely
# 192053  Always or almost always          Never or rarely
# 272843  Always or almost always  Always or almost always
# 59988   Always or almost always  Always or almost always
# 301459  Always or almost always                Sometimes
#
#                         ST80Q06                  ST80Q07  \
# 330800                Sometimes  Always or almost always
# 192053          Never or rarely  Always or almost always
# 272843  Always or almost always  Always or almost always
# 59988                     Often  Always or almost always
# 301459                Sometimes                    Often
#
#                         ST80Q08                  ST80Q09  \
# 330800                    Often                Sometimes
# 192053  Always or almost always  Always or almost always
# 272843  Always or almost always  Always or almost always
# 59988   Always or almost always                Sometimes
# 301459                    Often                    Often
#
#                         ST80Q10                  ST80Q11  TIMEINT   PV1MATH  \
# 330800                Sometimes                    Often     32.0  545.1083
# 192053  Always or almost always  Always or almost always      NaN  364.0053
# 272843                    Often  Always or almost always    111.0  476.2502
# 59988   Always or almost always  Always or almost always      NaN  249.5015
# 301459  Always or almost always                Sometimes      NaN  558.0386
#
#          PV2MATH   PV3MATH   PV4MATH   PV5MATH   PV1READ   PV2READ   PV3READ  \
# 330800  567.6975  565.3606  558.3502  560.6870  526.6316  607.6512  588.5877
# 192053  356.9949  359.3317  325.0584  342.1950  368.7227  352.0422  318.6812
# 272843  498.8394  452.1031  461.4504  476.2502  441.0515  545.3044  506.0091
# 59988   248.7225  235.4806  225.3544  299.3535  226.1302  330.3831  221.3186
# 301459  535.4494  572.8384  559.5965  555.7018  517.8779  524.2934  543.5401
#
#          PV4READ   PV5READ   PV1SCIE   PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 330800  540.9291  545.6950  460.4066  471.5964  485.5837  517.2883  500.5035
# 192053  394.1406  345.6877  398.5826  393.9202  342.6333  400.4476  395.7852
# 272843  451.4768  441.0515  432.7117  400.0746  386.0873  412.1969  432.7117
# 59988   227.7341  291.8897  151.6598  245.8411  215.0690  184.2969  286.8706
# 301459  563.5887  583.6374  531.1824  553.5621  550.7646  575.9418  561.9545

# %%
# renaming the selected columns so that it is easier to understand
df_selected.rename(columns=
                   {'CNT':'country', 
                    'OECD':'OECD', 
                    'ST01Q01':'international_grade',
                    'ST02Q01':'national_study_program', 
                    'ST04Q01':'gender',
                    'ST28Q01':'number_books',
                    'ST53Q01':'Learning_strategies_1',
                    'ST53Q02':'Learning_strategies_2',
                    'ST80Q01':'CA_TeacherEncouragesToReflectProblems',
                    'ST80Q04':'CA_GivesProblemThatRequireToThink',
                    'ST80Q05':'CA_AsksToUseOwnProcedures',
                    'ST80Q06':'CA_PresentsProblemsWithNoObviousSolutions',
                    'ST80Q07':'CA_PresentsProblemsInDifferentContexts',
                    'ST80Q08':'CA_HelpsLearnFromMistakes',
                    'ST80Q09':'CA_AsksForExplanation',
                    'ST80Q10':'CA_ApplyWhatTheyLearned',
                    'ST80Q11':'CA_ProblemWithMultipleSolutions',
                    'TIMEINT':'Computer_time'}, inplace=True)

# %%
#checking if columns were renamed
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time   PV1MATH   PV2MATH  \
# 0                           Often            NaN  406.8469  376.4683
#
#     PV3MATH   PV4MATH   PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ  \
# 0  344.5319  321.1637  381.9209  249.5762  254.342  406.8496  175.7053
#
#     PV5READ   PV1SCIE  PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE
# 0  218.5981  341.7009   408.84  348.2283  367.8105  392.9877

# %% [markdown]
# Each score is represented five time for each participants. so I am going to calculate an average value for each score, it will be easier to work with only one value.

# %%
df_selected['math_average'] =  (df_selected['PV1MATH'] + df_selected['PV2MATH']+ 
                                df_selected['PV3MATH'] + df_selected['PV4MATH'] + df_selected['PV5MATH'])/5
df_selected['reading_average'] = (df_selected ['PV1READ'] + df_selected['PV2READ']+ 
                          df_selected['PV3READ'] + df_selected ['PV4READ'] + df_selected['PV5READ'])/5
df_selected['science_average'] = (df_selected['PV1SCIE'] + df_selected ['PV2SCIE']+ 
                          df_selected['PV3SCIE'] + df_selected['PV4SCIE'] + df_selected['PV5SCIE'])/5

# %%
df_selected.head(1)
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
#
#   number_books Learning_strategies_1 Learning_strategies_2  \
# 0  0-10 books                    NaN                   NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time   PV1MATH   PV2MATH  \
# 0                           Often            NaN  406.8469  376.4683
#
#     PV3MATH   PV4MATH   PV5MATH   PV1READ  PV2READ   PV3READ   PV4READ  \
# 0  344.5319  321.1637  381.9209  249.5762  254.342  406.8496  175.7053
#
#     PV5READ   PV1SCIE  PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE  math_average  \
# 0  218.5981  341.7009   408.84  348.2283  367.8105  392.9877     366.18634
#
#    reading_average  science_average
# 0        261.01424        371.91348

# %%
#since I no longoer need the individuals values for the dataframe, I am going to simply drop them
df_selected.drop(['PV1MATH', 'PV2MATH','PV3MATH', 'PV4MATH','PV5MATH','PV1READ','PV2READ','PV3READ','PV4READ','PV5READ', 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE'], axis=1, inplace=True)

# %%
df_selected.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time  math_average  \
# 0                           Often            NaN     366.18634
# 1                             NaN            NaN     470.56396
# 2                             NaN            NaN     505.53824
# 3                 Never or rarely            NaN     449.45476
# 4                           Often            NaN     385.50398
#
#    reading_average  science_average
# 0        261.01424        371.91348
# 1        384.68832        478.12382
# 2        405.18154        486.60946
# 3        477.46376        453.97240
# 4        256.01010        367.15778

# %%
# I am now going to save the new dataframe to a csv file so that is quicker to laod 
df_selected.to_csv('PISA_cognition.csv', encoding='utf-8', index=False)

# %%
df_cognition = pd.read_csv('PISA_cognition.csv', encoding='utf-8')
df_cognition.head()
# Out:
#    country      OECD  international_grade  national_study_program  gender  \
# 0  Albania  Non-OECD                   10                     1.0  Female
# 1  Albania  Non-OECD                   10                     1.0  Female
# 2  Albania  Non-OECD                    9                     1.0  Female
# 3  Albania  Non-OECD                    9                     1.0  Female
# 4  Albania  Non-OECD                    9                     1.0  Female
#
#           number_books Learning_strategies_1  Learning_strategies_2  \
# 0          0-10 books                    NaN                    NaN
# 1       201-500 books      relating to known  Improve understanding
# 2  More than 500 books        Most important  Improve understanding
# 3         11-25 books      relating to known               new ways
# 4       101-200 books                    NaN                    NaN
#
#   CA_TeacherEncouragesToReflectProblems CA_GivesProblemThatRequireToThink  \
# 0               Always or almost always                         Sometimes
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3               Always or almost always                               NaN
# 4               Always or almost always                             Often
#
#   CA_AsksToUseOwnProcedures CA_PresentsProblemsWithNoObviousSolutions  \
# 0           Never or rarely                   Always or almost always
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                 Sometimes                                     Often
#
#   CA_PresentsProblemsInDifferentContexts CA_HelpsLearnFromMistakes  \
# 0                Always or almost always   Always or almost always
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                  Often                     Often
#
#      CA_AsksForExplanation CA_ApplyWhatTheyLearned  \
# 0  Always or almost always                   Often
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4  Always or almost always                   Often
#
#   CA_ProblemWithMultipleSolutions  Computer_time  math_average  \
# 0                           Often            NaN     366.18634
# 1                             NaN            NaN     470.56396
# 2                             NaN            NaN     505.53824
# 3                 Never or rarely            NaN     449.45476
# 4                           Often            NaN     385.50398
#
#    reading_average  science_average
# 0        261.01424        371.91348
# 1        384.68832        478.12382
# 2        405.18154        486.60946
# 3        477.46376        453.97240
# 4        256.01010        367.15778

# %%
df_cognition['math_average'].isnull().sum().sum(), df_cognition['reading_average'].isnull().sum().sum(), df_cognition['science_average'].isnull().sum().sum()
# Out:
# (0, 0, 0)

# %%
#sectioning the data in to 4 groups that I will need to use for later analysis(OECD, Non_OECD, female and male)
OECD = df_cognition.query('OECD == "OECD"')
Non_OECD = df_cognition.query('OECD=="Non-OECD"')
male= df_cognition.query('gender=="Male"')
female = df_cognition.query('gender=="Female"')
#verifying
OECD.shape[0], Non_OECD.shape[0], male.shape[0], female.shape[0]
# Out:
# (295416, 190074, 240426, 245064)

# %%
#checking null values in the computer time column, the non_OECD countries seem to be missing a lot of values. checking null values for female and male group
df_cognition['Computer_time'].isnull().sum().sum(), OECD['Computer_time'].isnull().sum().sum(), Non_OECD['Computer_time'].isnull().sum().sum(), female['Computer_time'].isnull().sum().sum(), male['Computer_time'].isnull().sum().sum()
# Out:
# (188416, 60938, 127478, 95416, 93000)

# %%
#replacing missing values by the mean for each group
#sub2['income'].fillna((sub2['income'].mean()), inplace=True)
OECD['Computer_time'].fillna((OECD['Computer_time'].mean()), inplace=True)
Non_OECD['Computer_time'].fillna((Non_OECD['Computer_time'].mean()), inplace=True)
female['Computer_time'].fillna((female['Computer_time'].mean()), inplace=True)
male['Computer_time'].fillna((male['Computer_time'].mean()), inplace=True)
# Out:
# C:\Users\gwiza\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#verifying if missing values were filled
OECD['Computer_time'].isnull().sum().sum(), Non_OECD['Computer_time'].isnull().sum().sum(), female['Computer_time'].isnull().sum().sum(), male['Computer_time'].isnull().sum().sum()
# Out:
# (0, 0, 0, 0)

# %% [markdown]
# ## Univariate Exploration
#
# > Now we are going to analyze the math, reading and science scores. we will also mostly try to understand th distributions scores. and the proportions of our group of interests, OECD, Non_OECD, boys and girls.

# %% [markdown]
# ## In general, Students Equally Succeed(or fail) in the field of Math, Reading and Science
# > My primary assumption would have been that students succeed more in one subject comparing to others. But I was pleased to see that based on this survey response, students tend to equally succeed (or fail) in all 3 subjects. The mean scores in Math, Reading and Science is the almost the same. the mode is is also very close to the mean and remain almost the same in all 3 subjects. <br>
# There is no subject where the average score is significantly higher or smaller than the others.
# It is important to quickly notice that the mean values are slightly below the average of 500. the test are scored on a 1000.

# %%
df_cognition['math_average'].mean(), df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()
# Out:
# (469.65123385442615, 472.0069640898506, 475.80809403002854)

# %%
#checking modes values to understand the most common  test scores
df_cognition['math_average'].mode(), df_cognition['reading_average'].mode(), df_cognition['science_average'].mode()
# Out:
# (0    479.36594
#  dtype: float64, 0    475.7957
#  dtype: float64, 0    475.88586
#  dtype: float64)

# %%
plt.figure(figsize=[6,5])
# plotting Math, Reading and Science Score to see if children tends to succeed more in one  
labels = ["Math Score", "Reading Score", "Science Score"]
usage = [df_cognition['math_average'].mean(),df_cognition['reading_average'].mean(), df_cognition['science_average'].mean()]

# Generating the y positions. Later, we'll use them to replace them with labels.
y_positions = range(len(labels))

# Creating our bar plot
plt.bar(y_positions, usage)
plt.xticks(y_positions, labels)
plt.ylabel("Score")
plt.title("Average Scores in Math, Reading and Science")
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# ## Specifics Colors for each group
# In this analysis, I will be comparing OECD and Non OECD countries. And Female and Male Students. In order to make the charts easier to read, I will assign to each group a color that I will keep using all the way to the end of the analysis.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Proportions of OECD and Non OECD Countries that particapated in the survey
#
# As I was getting familiar with the dataset, It seemed interesting to know the proportions of OECD and Non_OECD Countries participants  in the survey. there are clearly much more OECD countries participants as they accounts for 60.8% of the survey's participants.

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['OECD'].value_counts()
colors = ['#F4A460','#FFDEAD']
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',colors=colors,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# ## Proportion of Boys and Female Students in the survey
# The proportion of boys and girls who participated in the survey is almost equal

# %%
# code for the pie chart seen above
sorted_counts = df_cognition['gender'].value_counts()
colors = ['#FF69B4','#1E90FF']
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,autopct='%1.1f%%',colors=colors,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# ## Scores Distribution for OECD and Non_OECD Countries

# %%
plt.figure(figsize = [20, 12])

bins_hist = np.arange(0, 1000 + 1, 100)
# 1st row  (OECD Countries)
plt.subplot(2, 3, 1)
colors=['#F4A460']
plt.hist(OECD['math_average'], bins = bins_hist, alpha = 0.4, color=colors);
plt.hist(Non_OECD['math_average'], bins = bins_hist, alpha = 0.7, color=color);

plt.xticks(bins_hist)
plt.xlabel('Math Score Distribution');
plt.ylabel('Number of students')
plt.title("OECD Students");

plt.subplot(2, 3, 2)
plt.hist(OECD['reading_average'], bins = bins_hist,  alpha = 0.7, color=colors);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution');
plt.title("OECD Students");

plt.subplot(2, 3, 3)
plt.hist(OECD['science_average'], bins = bins_hist, alpha = 0.7, color=colors);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution');
plt.title("OECD Students");

# 2nd row (Non OECD Countries)

plt.subplot(2, 3, 4)
color = ['#800000']
plt.hist(Non_OECD['math_average'], bins = bins_hist, alpha = 0.9, color=color);

plt.xticks(bins_hist)
plt.xlabel('Math Score Distribution');
plt.ylabel('Number of students')
plt.title("Non OECD Students");

plt.subplot(2, 3, 5)
plt.hist(Non_OECD['reading_average'], bins = bins_hist,  alpha = 0.9, color=color);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution');
plt.title("Non OECD Students");

plt.subplot(2, 3, 6)
plt.hist(Non_OECD['science_average'], bins = bins_hist, alpha = 0.9, color=color);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution');
plt.title("Non OECD Students");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     157     try:
# --> 158         rgba = _colors_full_map.cache[c, alpha]
#     159     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('#FFDuAD', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-03c0aa7a909c> in <module>()
#       6 colors=['#F4A460']
#       7 plt.hist(OECD['math_average'], bins = bins_hist, alpha = 0.4, color=colors);
# ----> 8 plt.hist(Non_OECD['math_average'], bins = bins_hist, alpha = 0.7, color=color);
#       9
#      10 plt.xticks(bins_hist)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6547             color = [self._get_lines.get_next_color() for i in range(nx)]
#    6548         else:
# -> 6549             color = mcolors.to_rgba_array(color)
#    6550             if len(color) != nx:
#    6551                 error_message = (
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     257     result = np.empty((len(c), 4), float)
#     258     for i, cc in enumerate(c):
# --> 259         result[i] = to_rgba(cc, alpha)
#     260     return result
#     261
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     158         rgba = _colors_full_map.cache[c, alpha]
#     159     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 160         rgba = _to_rgba_no_colorcycle(c, alpha)
#     161         try:
#     162             _colors_full_map.cache[c, alpha] = rgba
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     202         except ValueError:
#     203             pass
# --> 204         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     205     # tuple color.
#     206     c = np.array(c)
#
# ValueError: Invalid RGBA argument: '#FFDuAD'

# %% [markdown]
# ## Scores Distribution for Girls and Boys

# %%
plt.figure(figsize = [20, 12])

bins_hist = np.arange(0, 1000 + 1, 100)
# 1st row  (OECD Countries)
plt.subplot(2, 3, 1)
plt.hist(female['math_average'], bins = bins_hist, alpha = 0.7);

plt.xticks(bins_hist)
plt.ylabel('Number of students')
plt.title("Female Students");
plt.xlabel('Math Score Distribution');
plt.subplot(2, 3, 2)
plt.hist(female['reading_average'], bins = bins_hist,  alpha = 0.7);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution');
plt.title("Female Students");

plt.subplot(2, 3, 3)
plt.hist(female['science_average'], bins = bins_hist, alpha = 0.7);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution');
plt.title("Female Students");

# 2nd row (Non OECD Countries)

plt.subplot(2, 3, 4)
plt.hist(male['math_average'], bins = bins_hist, alpha = 0.7);

plt.xticks(bins_hist)
plt.xlabel('Math Score Distribution');
plt.ylabel('Number of students')
plt.title("Male Students");

plt.subplot(2, 3, 5)
plt.hist(male['reading_average'], bins = bins_hist,  alpha = 0.7);

plt.xticks(bins_hist)
plt.xlabel('Reading Score Distribution');
plt.title("Male Students");

plt.subplot(2, 3, 6)
plt.hist(male['science_average'], bins = bins_hist, alpha = 0.7);

plt.xticks(bins_hist)
plt.xlabel('Science Score Distribution');
plt.title("Male  Students");

# %% [markdown]
# ## Computer Time Distribution
#
# Reviens sur ca plus tard. pour le moment on comment le survey truc

# %%
# fill missing values with df_cognition['Computer_time'].describe(), df_cognition['Computer_time'].mode()

# %%
Non_OECD_PC = Non_OECD['Computer_time'].dropna()
Non_OECD_PC.count()
# Out:
# 190074

# %%
# df_cognition['Computer_time'].hist();
# plt.title("computer time")
# plt.xlabel("Time in Minutes")
# plt.ylabel("number of students");

############### utilise ces bar rapprochee pour OECD and non_OECD

plt.figure(figsize = [20, 10])

bins_hist = np.arange(0,210, 10)
# 1st row  
plt.subplot(2, 2, 1)
plt.hist(OECD['Computer_time'], bins = bins_hist, alpha = 0.7);
plt.xticks(bins_hist)
plt.ylabel('Number of students')
plt.title("OECD Average time");
plt.xlabel('Time in minutes');


plt.subplot(2, 2, 2)
plt.hist(Non_OECD['Computer_time'], bins = bins_hist,  alpha = 0.7);
plt.xticks(bins_hist)
plt.xlabel('Time in Minutes');
plt.title("Non OECD Average computer time");

# 2nd row 
plt.subplot(2, 2, 3)
plt.hist(Non_OECD_PC, bins = bins_hist, alpha = 0.7);
plt.xticks(bins_hist)
plt.xlabel('Time in Minutes');
plt.title("Female Students Computer time");


plt.subplot(2, 2, 4)
plt.hist(male['Computer_time'], bins = bins_hist, alpha = 0.7);
plt.xticks(bins_hist)
plt.xlabel('Time in Minutes');
plt.ylabel('Number of students')
plt.title("Male Students");

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ## Cognitive Activity

# %%
df_cognition_copy = df_cognition.copy()

# %%
#df_likert= df_cognition.drop(['international_grade','national_study_program', 'number_books', 'Learning_strategies_1', 'Learning_strategies_2'], axis=1, inplace=True)
df_likert =df_cognition.copy()
df_likert.drop(['international_grade','national_study_program', 'number_books', 'Learning_strategies_1', 'Learning_strategies_2'], axis=1, inplace=True)

# %%
df_likert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Data columns (total 16 columns):
# country                                      485490 non-null object
# OECD                                         485490 non-null object
# gender                                       485490 non-null object
# CA_TeacherEncouragesToReflectProblems        314171 non-null object
# CA_GivesProblemThatRequireToThink            313521 non-null object
# CA_AsksToUseOwnProcedures                    312593 non-null object
# CA_PresentsProblemsWithNoObviousSolutions    312490 non-null object
# CA_PresentsProblemsInDifferentContexts       312521 non-null object
# CA_HelpsLearnFromMistakes                    312591 non-null object
# CA_AsksForExplanation                        311814 non-null object
# CA_ApplyWhatTheyLearned                      312305 non-null object
# CA_ProblemWithMultipleSolutions              312865 non-null object
# Computer_time                                297074 non-null float64
# math_average                                 485490 non-null float64
# reading_average                              485490 non-null float64
# science_average                              485490 non-null float64
# dtypes: float64(4), object(12)
# memory usage: 59.3+ MB

# %%
def unique_values(df, var_list):
     for var in var_list:
         print(var, ' Unique Values:\n', df[var].unique(), '\n')
unique_values(df_likert, df_likert.columns.tolist())
# Out:
# country  Unique Values:
#  ['Albania' 'United Arab Emirates' 'Argentina' 'Australia' 'Austria'
#  'Belgium' 'Bulgaria' 'Brazil' 'Canada' 'Switzerland' 'Chile' 'Colombia'
#  'Costa Rica' 'Czech Republic' 'Germany' 'Denmark' 'Spain' 'Estonia'
#  'Finland' 'France' 'United Kingdom' 'Greece' 'Hong Kong-China' 'Croatia'
#  'Hungary' 'Indonesia' 'Ireland' 'Iceland' 'Israel' 'Italy' 'Jordan'
#  'Japan' 'Kazakhstan' 'Korea' 'Liechtenstein' 'Lithuania' 'Luxembourg'
#  'Latvia' 'Macao-China' 'Mexico' 'Montenegro' 'Malaysia' 'Netherlands'
#  'Norway' 'New Zealand' 'Peru' 'Poland' 'Portugal' 'Qatar'
#  'China-Shanghai' 'Perm(Russian Federation)' 'Florida (USA)'
#  'Connecticut (USA)' 'Massachusetts (USA)' 'Romania' 'Russian Federation'
#  'Singapore' 'Serbia' 'Slovak Republic' 'Slovenia' 'Sweden'
#  'Chinese Taipei' 'Thailand' 'Tunisia' 'Turkey' 'Uruguay'
#  'United States of America' 'Vietnam']
#
# OECD  Unique Values:
#  ['Non-OECD' 'OECD']
#
# gender  Unique Values:
#  ['Female' 'Male']
#
# CA_TeacherEncouragesToReflectProblems  Unique Values:
#  ['Always or almost always' nan 'Never or rarely' 'Often' 'Sometimes']
#
# CA_GivesProblemThatRequireToThink  Unique Values:
#  ['Sometimes' nan 'Often' 'Always or almost always' 'Never or rarely']
#
# CA_AsksToUseOwnProcedures  Unique Values:
#  ['Never or rarely' nan 'Sometimes' 'Often' 'Always or almost always']
#
# CA_PresentsProblemsWithNoObviousSolutions  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_PresentsProblemsInDifferentContexts  Unique Values:
#  ['Always or almost always' nan 'Often' 'Never or rarely' 'Sometimes']
#
# CA_HelpsLearnFromMistakes  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_AsksForExplanation  Unique Values:
#  ['Always or almost always' nan 'Often' 'Sometimes' 'Never or rarely']
#
# CA_ApplyWhatTheyLearned  Unique Values:
#  ['Often' nan 'Always or almost always' 'Sometimes' 'Never or rarely']
#
# CA_ProblemWithMultipleSolutions  Unique Values:
#  ['Often' nan 'Never or rarely' 'Always or almost always' 'Sometimes']
#
# Computer_time  Unique Values:
#  [ nan  32.  92. 163.  81.  54.  39.  45. 111.  41. 124.  28.  26.  94.
#   11.  58.  64.  88.  51. 154.  99.  77. 114.  71.   2. 139.  86.  13.
#   75.  62.  69. 118. 206. 144.   6.  15. 150.  19. 137. 101.  21.  43.
#   96.  17.  34. 120. 107. 180. 129.   9.  84.  73.  30.  47.   4.   0.
#   56.  49.]
#
# math_average  Unique Values:
#  [366.18634 470.56396 505.53824 ... 681.73392 667.86884 472.90076]
#
# reading_average  Unique Values:
#  [261.01424 384.68832 405.18154 ... 663.02994 565.07616 525.57658]
#
# science_average  Unique Values:
#  [371.91348 478.12382 486.60946 ... 743.3234  758.24318 513.83816]

# %%
#df.pivot(index='date', columns='variable', values='value')
df_likert.groupby('Albania')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-87fc8e6b0a26> in <module>()
#       1 #df.pivot(index='date', columns='variable', values='value')
# ----> 2 df_likert.groupby('Albania')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'Albania'

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!

# %% [markdown]
# ## References:
# * PISA 2012 contest winner: http://mi2.mini.pw.edu.pl:8080/SmarterPoland/PISAcontest/
# * What is PISA: http://www.oecd.org/pisa/
# * OECD: https://en.wikipedia.org/wiki/OECD
# * PISA 2012 Countries : http://www.oecd.org/pisa/aboutpisa/pisa-2012-participants.htm
# * PISA 2012 Data analysis Manual:http://archivos.agenciaeducacion.cl/Manual_de_Analisis_de_datos_SPSS_version_ingles.pdf
# * PISA Data Exploration : https://github.com/brunoassisp/PISA-Data-Viz-project/blob/master/PISA_EDA.ipynb
# * Jasccyang github repository : https://github.com/jasccyang/PISA2012/blob/master/Reducing%20File%20Size.ipynb
# * Seby Sbirna Github repository: https://github.com/seby-sbirna/Data-Analyst-Nanodegree-Project-Portfolio/blob/master/Project%205%20-%20Communicate%20Data%20Findings/Project%205%20-%20Sebastian%20Sbirna.ipynb
# * Visualization: https://www.researchgate.net/figure/Responses-to-Relating-to-your-last-five-publications-how-often-did-you-incorporate-the_fig1_328394497
# * Udacity Classroom: https://classroom.udacity.com/nanodegrees/nd002/parts/9f7e8991-8bfb-4103-8307-3b6f93f0ecc7
# * BarPlot with matplotlib: https://towardsdatascience.com/data-science-with-python-intro-to-data-visualization-and-matplotlib-5f799b7c6d82
# * Pivot table: https://www.dataquest.io/blog/pandas-pivot-table
# * Pandas stack:https://stackoverflow.com/questions/49098380/pandas-condense-survey-results
# * Reshaping Dataframe: https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
